# %%
from nltk.tokenize import sent_tokenize, word_tokenize
import gensim
from gensim.models import Word2Vec
import pandas as pd
import re
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras import backend as K

# %% [markdown]
# # Word2vec

# %%
Train = pd.read_csv('SentimentAnalysis/train.csv')

# %%
Train.dropna(inplace=True)

# %%
X_train = Train.text

# %%
def clean(data):
    #Removing URLs with a regular expression
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    data = url_pattern.sub(r'', data)

    # Remove Emails
    data = re.sub('\S*@\S*\s?', '', data)

    # Remove new line characters
    data = re.sub('\s+', ' ', data)

    # Remove distracting single quotes
    data = re.sub("\'", "", data)
        
    return data

# %%
data = []
data_to_list = X_train.values.tolist()
for i in range(len(data_to_list)):
    for i in sent_tokenize(clean(data_to_list[i])):
        temp = []

        # tokenize the sentence into words
        for j in word_tokenize(i):
            temp.append(j.lower())
    data.append(temp)

# %%
data
# Out:
# [['i', '`', 'd', 'have', 'responded', ',', 'if', 'i', 'were', 'going'],
#  ['!'],
#  ['my', 'boss', 'is', 'bullying', 'me', '...'],
#  ['leave', 'me', 'alone'],
#  ['sons',
#   'of',
#   '****',
#   ',',
#   'why',
#   'couldn',
#   '`',
#   't',
#   'they',
#   'put',
#   'them',
#   'on',
#   'the',
#   'releases',
#   'we',
#   'already',
#   'bought'],
#  ['-',
#   'some',
#   'shameless',
#   'plugging',
#   'for',
#   'the',
#   'best',
#   'rangers',
#   'forum',
#   'on',
#   'earth'],
#  ['2am',
#   'feedings',
#   'for',
#   'the',
#   'baby',
#   'are',
#   'fun',
#   'when',
#   'he',
#   'is',
#   'all',
#   'smiles',
#   'and',
#   'coos'],
#  ['soooo', 'high'],
#  ['both', 'of', 'you'],
#  ['hehe', '...', '(', 'is', 'that', 'possible', '!', '?', ')'],
#  ['as',
#   'much',
#   'as',
#   'i',
#   'love',
#   'to',
#   'be',
#   'hopeful',
#   ',',
#   'i',
#   'reckon',
#   'the',
#   'chances',
#   'are',
#   'minimal',
#   '=p',
#   'i',
#   '`',
#   'm',
#   'never',
#   'gon',
#   'na',
#   'get',
#   'my',
#   'cake',
#   'and',
#   'stuff'],
#  ['i',
#   'really',
#   'really',
#   'like',
#   'the',
#   'song',
#   'love',
#   'story',
#   'by',
#   'taylor',
#   'swift'],
#  ['my', 'sharpie', 'is', 'running', 'dangerously', 'low', 'on', 'ink'],
#  ['i',
#   'want',
#   'to',
#   'go',
#   'to',
#   'music',
#   'tonight',
#   'but',
#   'i',
#   'lost',
#   'my',
#   'voice',
#   '.'],
#  ['test', 'test', 'from', 'the', 'lg', 'env2'],
#  ['uh', 'oh', ',', 'i', 'am', 'sunburned'],
#  ['s',
#   '`',
#   'ok',
#   ',',
#   'trying',
#   'to',
#   'plot',
#   'alternatives',
#   'as',
#   'we',
#   'speak',
#   '*sigh*'],
#  ['if', 'i', 'didnt', 'have', 'a', 'hat', 'on', 'it', 'would', 'look', '...'],
#  ['is', 'back', 'home', 'now', 'gon', 'na', 'miss', 'every', 'one'],
#  ['hes', 'just', 'not', 'that', 'into', 'you'],
#  ['<', '3', '<', '3'],
#  ['can', '`', 't', 'wait', 'to', 'have', 'a', 'dragon', 'pet'],
#  ['is',
#   'cleaning',
#   'the',
#   'house',
#   'for',
#   'her',
#   'family',
#   'who',
#   'is',
#   'comming',
#   'later',
#   'today..'],
#  ['i',
#   'thought',
#   'win7',
#   'was',
#   'supposed',
#   'to',
#   'put',
#   'an',
#   'end',
#   'to',
#   'the',
#   'constant',
#   'rebootiness'],
#  ['see',
#   'wat',
#   'i',
#   'mean',
#   'bout',
#   'foll0w',
#   'friidays',
#   '...',
#   'it',
#   '`',
#   's',
#   'called',
#   'lose',
#   'f0llowers',
#   'friday',
#   '...',
#   'smh'],
#  ['the',
#   'free',
#   'fillin',
#   '`',
#   'app',
#   'on',
#   'my',
#   'ipod',
#   'is',
#   'fun',
#   ',',
#   'im',
#   'addicted'],
#  ['i', '`', 'm', 'sorry', '.'],
#  ['on',
#   'the',
#   'way',
#   'to',
#   'malaysia',
#   '...',
#   'no',
#   'internet',
#   'access',
#   'to',
#   'twit'],
#  ['whassqoodd', '?'],
#  ['went',
#   'to',
#   'sleep',
#   'and',
#   'there',
#   'is',
#   'a',
#   'power',
#   'cut',
#   'in',
#   'noida',
#   'power',
#   'back',
#   'up',
#   'not',
#   'working',
#   'too'],
#  ['quite', '...', '.heavenly', 'isn', '`', '****', '?'],
#  ['fighting', 'dahye', 'unni', '!'],
#  ['if',
#   'it',
#   'is',
#   'any',
#   'consolation',
#   'i',
#   'got',
#   'my',
#   'bmi',
#   'tested',
#   'hahaha',
#   'it',
#   'says',
#   'i',
#   'am',
#   'obesed',
#   'well',
#   'so',
#   'much',
#   'for',
#   'being',
#   'unhappy',
#   'for',
#   'about',
#   '10',
#   'minutes',
#   '.'],
#  ['cute', 'kids', '.'],
#  ['i', 'hope', 'we', 'play', 'army', '.'],
#  ['tears', 'for', 'fears', 'vs', 'eric', 'prydz', ',', 'dj', 'hero'],
#  ['i', 'still', 'miss', 'ny'],
#  ['just',
#   'in',
#   'case',
#   'you',
#   'wonder',
#   ',',
#   'we',
#   'are',
#   'really',
#   'busy',
#   'today',
#   'and',
#   'this',
#   'coming',
#   'with',
#   'with',
#   'adding',
#   'tons',
#   'of',
#   'new',
#   'blogs',
#   'and',
#   'updates',
#   'stay',
#   'tuned'],
#  ['the',
#   'last',
#   'day',
#   'o',
#   '`',
#   'school',
#   'was',
#   'today',
#   '...',
#   '.sniffle',
#   '...',
#   '.'],
#  ['a',
#   'little',
#   'happy',
#   'for',
#   'the',
#   'wine',
#   'jeje',
#   'ok',
#   'it',
#   '`',
#   'sm',
#   'my',
#   'free',
#   'time',
#   'so',
#   'who',
#   'cares',
#   ',',
#   'jaja',
#   'i',
#   'love',
#   'this',
#   'day'],
#  ['hoping',
#   'theyre',
#   'not',
#   'going',
#   'to',
#   'write',
#   'it',
#   'off',
#   ',',
#   'crossing',
#   'fingers',
#   'and',
#   'waiting'],
#  ['im',
#   'an',
#   'avid',
#   'fan',
#   'of',
#   '****',
#   'magazine',
#   'and',
#   'i',
#   'love',
#   'your',
#   'magazines'],
#  ['!'],
#  ['pearcy', 'has', 'that', 'hott', 'bad', 'boy', 'look'],
#  ['would', 'love', 'to', 'help', 'convert', 'her', 'vids.ï¿½'],
#  ['how', 'old', 'do', 'i', 'feel', '?'],
#  ['egh',
#   'blah',
#   'and',
#   'boooooooooooo',
#   'i',
#   'dunno',
#   'wan',
#   'na',
#   'go',
#   'to',
#   'work',
#   'hangovers',
#   'suckkkkkk',
#   'im',
#   'a',
#   'drunk',
#   'mess',
#   '!'],
#  [':', 'visiting', 'my', 'friendster', 'and', 'facebook'],
#  ['i',
#   'donbt',
#   'like',
#   'to',
#   'peel',
#   'prawns',
#   ',',
#   'i',
#   'also',
#   'dont',
#   'like',
#   'going',
#   'shopping',
#   ',',
#   'running',
#   'out',
#   'of',
#   'money',
#   'and',
#   'crawling',
#   'round',
#   'the',
#   'car',
#   'looking',
#   'for',
#   'more'],
#  ['i',
#   'got',
#   'a',
#   'new',
#   'one',
#   'last',
#   'week',
#   'and',
#   'i',
#   '`',
#   'm',
#   'not',
#   'thrilled',
#   'at',
#   'all',
#   'with',
#   'mine',
#   '.'],
#  ['then',
#   'you',
#   'should',
#   'check',
#   'out',
#   'and',
#   'connect',
#   'with',
#   'other',
#   'tweeple',
#   'who',
#   'hate',
#   'twitter'],
#  ['also',
#   'bored',
#   'at',
#   'school',
#   ',',
#   'its',
#   'my',
#   'third',
#   'freelesson',
#   '(',
#   'freistunde',
#   ')'],
#  ['both', 'of', 'us', 'i', 'guess', '...'],
#  ['it',
#   'is',
#   '****',
#   '...',
#   'u',
#   'have',
#   'dissappointed',
#   'me',
#   'that',
#   'past',
#   'few',
#   'days'],
#  ['romance', 'zero', 'is', 'funny'],
#  ['i',
#   '`',
#   'd',
#   'rather',
#   'do',
#   'the',
#   'early',
#   'run..but',
#   'i',
#   'am',
#   'a',
#   'morning',
#   'runner'],
#  ['bah',
#   'a',
#   'coworker',
#   'ran',
#   'into',
#   'work',
#   'late',
#   'and',
#   'her',
#   'bag',
#   'smacked',
#   'into',
#   'my',
#   'knee',
#   'it',
#   'really',
#   'hurts',
#   'now'],
#  ['will', 'be', 'back', 'later', '.'],
#  ['torn', 'ace', 'of', 'hearts', '#', 'hunchback'],
#  ['what', 'fun', 'are', 'you', 'speaking', 'of', '?'],
#  ['i',
#   'lost',
#   'all',
#   'my',
#   'friends',
#   ',',
#   'i',
#   '`',
#   'm',
#   'alone',
#   'and',
#   'sleepy..i',
#   'wan',
#   'na',
#   'go',
#   'home'],
#  ['haha', 'yes'],
#  ['i', 'give', 'in', 'to', 'easily'],
#  ['our', 'wine', 'was', 'a', 'red'],
#  ['im', 'jealous', '...', '.'],
#  ['is', 'at', 'a', 'photoshoot', '.'],
#  ['he', '`', 's', 'a', 'good', 'friend', '.'],
#  ['boo',
#   'it',
#   '`',
#   's',
#   'gon',
#   'na',
#   'soggy',
#   'and',
#   'i',
#   '`',
#   'm',
#   'at',
#   'work',
#   'right',
#   'before',
#   'playing'],
#  ['chilliin'],
#  ['if', 'you', 'know', 'such', 'agent', ',', 'do', 'let', 'me', 'know'],
#  ['i', 'still', 'smell', 'of', 'smoke', '#', 'kitchenfire'],
#  ['lol'],
#  ['i',
#   'promise',
#   'to',
#   'buy',
#   'you',
#   'a',
#   'drink',
#   'and',
#   'take',
#   'rad',
#   'pics',
#   'for',
#   'your',
#   'fb',
#   '/',
#   'blog',
#   '/',
#   'flickr.',
#   ',',
#   'etc'],
#  ['you',
#   'can',
#   'ride',
#   'one',
#   ',',
#   'you',
#   'can',
#   'catch',
#   'one',
#   ',',
#   'but',
#   'its',
#   'not',
#   'summer',
#   'til',
#   'you',
#   'pop',
#   'open',
#   'one',
#   '?'],
#  ['so',
#   'gor-juz',
#   'yea',
#   'i',
#   'kno',
#   'i',
#   'asked',
#   'her',
#   'yesterday',
#   'when',
#   'we',
#   'were',
#   'at',
#   'tha',
#   'hospital',
#   'if',
#   'she',
#   'talked',
#   'to',
#   'u',
#   'and',
#   'she',
#   'said',
#   'no'],
#  ['i',
#   '`',
#   'll',
#   'probably',
#   'head',
#   'to',
#   'the',
#   'guttah',
#   'later',
#   'on',
#   'tonight'],
#  ['baddd', '.'],
#  ['my', 'sources', 'say', 'no'],
#  ['i', 'am', 'sooo', 'tired'],
#  ['hey',
#   ',',
#   'you',
#   'change',
#   'your',
#   'twitter',
#   'account',
#   ',',
#   'and',
#   'you',
#   'didn',
#   '`',
#   't',
#   'even',
#   'tell',
#   'me',
#   '...'],
#  ['thank', 'yyyyyyyyyoooooooooouuuuu', '!'],
#  ['lucky',
#   'kid',
#   '...',
#   'i',
#   'so',
#   'wan',
#   'na',
#   'see',
#   'loserville',
#   'pity',
#   'im',
#   'in',
#   'oz',
#   '...',
#   '.'],
#  ['fell', 'asleep', 'waiting', 'for', 'my', 'ride', '!'],
#  ['with', 'a', 'flu', 'like', 'thing', '.'],
#  ['still',
#   'no',
#   'reply',
#   'from',
#   'about',
#   'my',
#   'simfinger',
#   'problem',
#   'so',
#   'no',
#   'irape',
#   'parody',
#   'video',
#   'until',
#   'i',
#   'get',
#   'a',
#   'response',
#   ',',
#   'sorry',
#   'guys'],
#  ['and', 'enjoy', 'the', 'holiday', '(', 'uk', ')'],
#  ['miles',
#   'from',
#   'you',
#   'i',
#   '`',
#   'm',
#   'in',
#   'essex',
#   'so',
#   'give',
#   'me',
#   'plenty',
#   'of',
#   'warning',
#   'so',
#   'i',
#   'can',
#   'arrive',
#   'in',
#   'time',
#   'to',
#   'get',
#   'at',
#   'least',
#   'one',
#   'of',
#   'those',
#   'free',
#   'beers',
#   '.'],
#  ['his',
#   'snoring',
#   'is',
#   'so',
#   'annoying',
#   'n',
#   'it',
#   'keeps',
#   'me',
#   'from',
#   'sleeping',
#   '(',
#   'like',
#   'right',
#   'now',
#   ',',
#   'lol',
#   ')',
#   'but',
#   'i',
#   'honestly',
#   'wud',
#   'miss',
#   'it',
#   'if',
#   'it',
#   'eva',
#   'left',
#   'i',
#   'love',
#   'him',
#   '.'],
#  ['i',
#   'miss',
#   'you',
#   'bby',
#   'wish',
#   'you',
#   'were',
#   'going',
#   'tomorrow',
#   'to',
#   'make',
#   'me',
#   'do',
#   'good',
#   '.'],
#  ['well',
#   'what',
#   'im',
#   'working',
#   'on',
#   'isn',
#   '`',
#   't',
#   'quite',
#   'ready',
#   'to',
#   'post',
#   'about',
#   'publicly',
#   '(',
#   'still',
#   'beta',
#   'testing',
#   ')',
#   'but',
#   'its',
#   'a',
#   'cool',
#   'new',
#   'script',
#   'i',
#   'coded'],
#  ['love', 'it', 'there'],
#  ['_mounce', 'yes', 'and', 'it', 'lasts', 'way', 'past', 'my', 'bedtime', '!'],
#  ['*just', 'joined', 'twitter', '...', '*'],
#  ['waiting',
#   'for',
#   'sleeping',
#   'pills',
#   'to',
#   'kick',
#   'in',
#   '...',
#   'gon',
#   'na',
#   'be',
#   'so',
#   'tired',
#   'at',
#   'work',
#   'tomorrow'],
#  ['eating',
#   'ice',
#   'cream',
#   'and',
#   'then',
#   'getting',
#   'ready',
#   'for',
#   'graduation',
#   '.'],
#  ['happy', 'mothers', 'day', 'to', 'all', 'you', 'mums', 'out', 'there'],
#  ['can', 'we', 'get', 'her', 'back', '?'],
#  ['hemp', 'cloth', 'is', 'marvelous', 'but', 'unfortunately', 'no'],
#  ['nighty', 'night'],
#  ['we',
#   'saw',
#   'that',
#   'in',
#   'none',
#   '3d',
#   '-',
#   'the',
#   'baddie',
#   '`',
#   's',
#   'the',
#   'best'],
#  ['pretty'],
#  ['certainly', 'not', 'cheers', 'than', ',', 'huh', '?'],
#  ['ouch', '!'],
#  ['i',
#   'realy',
#   'wanted',
#   'to',
#   'go',
#   'out',
#   'cause',
#   'its',
#   'so',
#   'nice',
#   'but',
#   'everybodys',
#   'busy'],
#  ['yourbiggestfan',
#   'i',
#   '`',
#   'm',
#   'a',
#   're-al',
#   'big',
#   'fan',
#   'of',
#   'you-rs',
#   '.'],
#  ['!'],
#  ['cool',
#   'i',
#   'wear',
#   'black',
#   'most',
#   'of',
#   'the',
#   'time',
#   'when',
#   'i',
#   'go',
#   'out'],
#  ['thanks',
#   'for',
#   'reblipping',
#   'my',
#   'song',
#   'have',
#   'a',
#   'nice',
#   'day',
#   '****'],
#  ['have',
#   'a',
#   'safe',
#   'trip',
#   'joshy',
#   'poo',
#   '...',
#   '...',
#   '.you',
#   '`',
#   'll',
#   'knock',
#   'them',
#   'dead',
#   'at',
#   'your',
#   'speech'],
#  ['woof', ',', 'i', 'wish', 'i', 'was', 'allowed', 'to', 'go'],
#  ['my',
#   'email',
#   'adress',
#   'add',
#   'me',
#   'loco_crime_1st.com',
#   'add',
#   'me',
#   'leave',
#   'some',
#   'comment'],
#  ['has', 'tickets', '...', '...', '.', '?'],
#  ['also', ',', 'i', 'got', 'a', 'giant', 'teacup', 'tonight', '!'],
#  ['yes', '?'],
#  ['he',
#   'works',
#   '7',
#   'days',
#   'a',
#   'week',
#   'almost',
#   'all',
#   'day',
#   'and',
#   'still',
#   'tries',
#   'to',
#   'go',
#   'to',
#   'sf',
#   'with',
#   'all',
#   'of',
#   'us'],
#  ['so',
#   'many',
#   'tests',
#   'todayyy',
#   'i',
#   'don',
#   '`',
#   't',
#   'feel',
#   'confident',
#   'about',
#   'anyy',
#   '.'],
#  ['?'],
#  ['hahaa', 'your', 'awesomee', '!'],
#  ['star', 'trek', 'was', 'freaking', 'awesomeeeee'],
#  ['i',
#   'hate',
#   'fallout',
#   '3',
#   'it',
#   'keeps',
#   'making',
#   'me',
#   'jump',
#   ',',
#   'i',
#   '`',
#   'm',
#   'also',
#   'low',
#   'on',
#   'health',
#   ',',
#   'money',
#   ',',
#   'ammo',
#   'and',
#   'food',
#   'don',
#   '`',
#   't',
#   'worry',
#   'i',
#   '`',
#   'll',
#   'get',
#   'through',
#   'it',
#   '.'],
#  ['on',
#   'my',
#   'itunes',
#   ',',
#   'but',
#   'then',
#   'i',
#   'lost',
#   'all',
#   'my',
#   'songs',
#   '.'],
#  ['the',
#   'sun',
#   'must',
#   'be',
#   'too',
#   'tired',
#   'to',
#   'come',
#   'out',
#   'and',
#   'play',
#   'heading',
#   'to',
#   'victoria',
#   'gardens',
#   'for',
#   'some',
#   'impulse',
#   'buys',
#   'haha'],
#  ['not',
#   'looking',
#   'forward',
#   'to',
#   'next',
#   'week',
#   ':',
#   'maths',
#   ',',
#   'geography',
#   ',',
#   'english',
#   'and',
#   'french',
#   'exams',
#   ',',
#   'totalling',
#   '7',
#   'hours'],
#  ['!'],
#  ['not', 'well'],
#  ['not', 'a', 'prob', 'hun'],
#  ['at',
#   'dads',
#   ',',
#   'watching',
#   'some',
#   'mtv',
#   'and',
#   'am',
#   'going',
#   'on',
#   'sims2',
#   'in',
#   'a',
#   'minutee'],
#  ['absolutely'],
#  ['what', '`', 's', 'the', 'matter', 'chickadee', '?'],
#  ['when', 'will', 'your', 'cd', 'be', 'out', '?'],
#  ['nothing',
#   'spesh',
#   ',',
#   'but',
#   'a',
#   'good',
#   'bank',
#   'holiday',
#   'monday',
#   'nonetheless'],
#  ['lmao', 'i', 'love', 'him', 'too'],
#  ['those',
#   'splinters',
#   'look',
#   'very',
#   'painful',
#   '...',
#   'but',
#   'you',
#   'were',
#   'being',
#   'very',
#   'heroic',
#   'saving',
#   'mr.',
#   'pickle'],
#  ['why', 'are', 'you', 'sad', '?'],
#  ['so', 'be', 'nice', 'to', 'yer', 'mom'],
#  ['age', 'of', 'the', 'instant', 'gratification', '...', '.'],
#  ['...', 'naaaah', '!'],
#  ['i',
#   'cuss',
#   'like',
#   'that',
#   'in',
#   'a',
#   'matter',
#   'of',
#   'minutes',
#   ',',
#   'but',
#   'didn',
#   '`',
#   't',
#   'know',
#   'until',
#   'now',
#   'there',
#   'is',
#   'a',
#   'reward',
#   'for',
#   'it',
#   '.'],
#  ['humous', 'and', 'dorito', '`', 's', '...', '.', 'oh', 'yes'],
#  ['missed',
#   'all',
#   'the',
#   'awesome',
#   'weather',
#   ',',
#   'because',
#   'she',
#   'was',
#   'in',
#   'a',
#   'movie',
#   '!'],
#  ['we',
#   'had',
#   'a',
#   'group',
#   'of',
#   'pilots',
#   'from',
#   'a',
#   'large',
#   'airline',
#   'come',
#   'in',
#   'last',
#   'night',
#   'so',
#   'it',
#   'was',
#   'too',
#   'much',
#   'drink'],
#  ['if',
#   'i',
#   'was',
#   'in',
#   'good',
#   'evans',
#   ',',
#   'i',
#   '`',
#   'd',
#   'call',
#   'childline'],
#  ['unfortunatley',
#   ',',
#   'aerlingus',
#   'no',
#   'longer',
#   'fly',
#   'to',
#   'copenhagen',
#   'so',
#   'we',
#   '`',
#   're',
#   'have',
#   'to',
#   'fly',
#   'ryanair',
#   'to',
#   'billund',
#   'and',
#   'drive',
#   'up',
#   'to',
#   'copenhagen',
#   'one',
#   'of',
#   'the',
#   'days',
#   '!'],
#  ['that', 'sucks', ',', 'tho', '.'],
#  ['hate', 'fighting'],
#  ['i',
#   'didnt',
#   'want',
#   'her',
#   'to',
#   'win',
#   ',',
#   'but',
#   'she',
#   'put',
#   'up',
#   'a',
#   'good',
#   'fight..lol'],
#  ['car-warmed', 'sprite', 'tastes', 'like', 'sore', 'throat'],
#  ['just', 'came', '11th', 'in', 'cross', 'country', 'and', 'beat', 'dumbo'],
#  ['candle', 'wax', 'is', 'very', 'enjoyable', '.'],
#  ['i',
#   'suppose',
#   'that',
#   '`',
#   's',
#   'why',
#   'she',
#   '`',
#   's',
#   'so',
#   'endearing',
#   '--',
#   'because',
#   'we',
#   'can',
#   'relate',
#   'to',
#   'her'],
#  ['going',
#   'to',
#   'get',
#   'my',
#   'hair',
#   'done',
#   'but',
#   'im',
#   'arraving',
#   'late',
#   'got',
#   'my',
#   'cousins',
#   'babtizm',
#   'or',
#   'whatever',
#   'you',
#   'spell',
#   'it'],
#  ['?'],
#  ['i', 'hate', 'my', 'computer', 'so', 'much..'],
#  ['going',
#   'to',
#   'do',
#   'my',
#   'big',
#   'walk',
#   'today',
#   '20',
#   'or',
#   'so',
#   'miles'],
#  ['lmfao', '!'],
#  ['it', 'in', 'the', 'morning'],
#  ['me', 'neither'],
#  ['yeah'],
#  ['forgot', 'i', 'still', 'have', 'washing', 'in', 'my', 'machine'],
#  ['_laurie',
#   'sending',
#   'love',
#   ',',
#   'blessings',
#   '&',
#   'healing',
#   'thoughts',
#   'to',
#   'you',
#   '&',
#   'family',
#   'peace'],
#  ['my', 'back', 'hurts', '...', 'really', 'bad'],
#  ['ah', 'yes', ',', 'i', 'know', 'that', 'feeling'],
#  ['night', 'of', 'the', 'cookers', 'with', 'my', 'dad'],
#  ['may', 'schedule', 'has', 'been', 'brutal'],
#  ['nope', 'i', 'am', 'in', 'coquitlam'],
#  ['lol'],
#  ['#',
#   'lichfield',
#   '#',
#   'tweetup',
#   'sounds',
#   'like',
#   'fun',
#   'hope',
#   'to',
#   'see',
#   'you',
#   'and',
#   'everyone',
#   'else',
#   'there',
#   '!'],
#  ['ah', '...', 'probably', 'not', '.'],
#  ['!'],
#  ['but', 'i', '`', 'm', 'actually', 'excited', 'about', 'this', 'summer', '!'],
#  ['good', 'morning'],
#  ['its', 'the', 'best', 'show', 'ever', '!'],
#  ['^es'],
#  ['i',
#   'think',
#   'iv',
#   'hurt',
#   'my',
#   'tooth',
#   'and',
#   'eilish',
#   'and',
#   'cassie',
#   'are',
#   'having',
#   'a',
#   'drawing',
#   'competiton',
#   'to',
#   'draw',
#   'cookies',
#   'and',
#   'pineapples',
#   'haha',
#   ':',
#   'l',
#   '.'],
#  ['text', 'or', '...', 'reply', 'please', '!'],
#  ['or', 'even', 'nooooo', 'not', 'the', 'secret', 'namerebecca', 'please'],
#  ['lol'],
#  ['i', 'need', 'to', 'get', 'my', 'computer', 'fixed'],
#  ['really',
#   'hopes',
#   'her',
#   'car',
#   '`',
#   's',
#   'illness',
#   'is',
#   'not',
#   'terminal',
#   '...'],
#  ['all',
#   'the',
#   'cool',
#   'people',
#   'i',
#   'want',
#   'to',
#   'find',
#   'for',
#   'following',
#   'today',
#   'are',
#   '#',
#   'english',
#   ',',
#   'and',
#   'i',
#   'guess',
#   'the',
#   'english',
#   'don',
#   '`',
#   't',
#   'tweet',
#   '.'],
#  ['no',
#   'sir',
#   '...',
#   'i',
#   'woulda',
#   'put',
#   'honey',
#   '...',
#   'but',
#   'i',
#   'don',
#   '`',
#   't',
#   'have',
#   'any'],
#  ['haha'],
#  ['(', ':', 'x'],
#  ['i',
#   '`',
#   'm',
#   'sad',
#   'that',
#   'i',
#   'missed',
#   'you',
#   'guys',
#   'last',
#   'night',
#   '!'],
#  ['finally',
#   'got',
#   'a',
#   'call',
#   'for',
#   'marriage',
#   'counseling',
#   '3',
#   'days',
#   'late',
#   '...',
#   '.'],
#  ['ok', 'then'],
#  ['_420', 'why', 'baby', '?'],
#  ['...', 'stupid', 'dead', 'rats'],
#  ['except',
#   'i',
#   'don',
#   '`',
#   't',
#   'know',
#   'how',
#   'to',
#   'swim',
#   'so',
#   'i',
#   'can',
#   '`',
#   't',
#   'get',
#   'in'],
#  ['lost',
#   'my',
#   'tooth',
#   '2day',
#   'whilst',
#   'i',
#   'was',
#   'eating',
#   'gum',
#   '...',
#   'oww'],
#  ['<', '3'],
#  ['lol'],
#  ['*phew*',
#   'will',
#   'make',
#   'a',
#   'note',
#   'in',
#   'case',
#   'anyone',
#   'else',
#   'runs',
#   'into',
#   'the',
#   'same',
#   'issueï¿½'],
#  ['!'],
#  ['this',
#   'diet',
#   'is',
#   'killing',
#   'me',
#   'but',
#   'i',
#   'can',
#   '`',
#   't',
#   'eat',
#   'after',
#   '8pm'],
#  ['i', 'talk', 'to', 'you'],
#  ['im',
#   'soo',
#   'bored',
#   '...',
#   'im',
#   'deffo',
#   'missing',
#   'my',
#   'music',
#   'channels'],
#  ['nite', 'nite', 'bday', 'girl', 'have', 'fun', 'at', 'concert'],
#  ['getting', 'a', 'bit', 'twitchy', 'now'],
#  ['either',
#   'i',
#   'can',
#   '`',
#   't',
#   'get',
#   'on',
#   'or',
#   'the',
#   'replies',
#   'don',
#   '`',
#   't',
#   'turn',
#   'up',
#   '!'],
#  ['lost', 'my', 'voice', 'a', 'couple', 'day', 'ago', '.'],
#  ['-', 'hate', 'when', 'my', 'parked', 'car', 'gets', 'hit'],
#  ['i', '`', 'm', 'waiting', 'too', '!'],
#  ['*huggles*'],
#  ['****',
#   'my',
#   'cyberstalking',
#   'skills',
#   'the',
#   'internet',
#   '=',
#   'no',
#   'more',
#   'privacy',
#   '.'],
#  ['going', 'to', 'bed', 'its', 'late', 'and', 'i', 'have', 'headache'],
#  ['happy',
#   'mother',
#   '`',
#   's',
#   'day',
#   'to',
#   'all',
#   'moms',
#   'out',
#   'there',
#   '...'],
#  ['grabbing', 'coffee', 'from', 'then', 'making', 'mom', 'breakfast'],
#  ['im',
#   'thinking',
#   'that',
#   'im',
#   'going',
#   'to',
#   'have',
#   'fun',
#   'tonight',
#   '...',
#   '.and',
#   'maybe',
#   'some',
#   'changes',
#   'are',
#   'coming'],
#  ['before', 'the', 'major', 'chop', '.'],
#  ['and', 'thank', 'you', '!'],
#  ['just', 'got', 'up', 'and', 'updated', 'my', 'ipod'],
#  ['i',
#   'don',
#   '`',
#   't',
#   'knowwww',
#   'plan',
#   'plan',
#   'before',
#   'you',
#   'go',
#   'to',
#   'us',
#   '!'],
#  ['we',
#   'never',
#   'miss',
#   'icarly',
#   '-',
#   'my',
#   'son',
#   'has',
#   'a',
#   'huge',
#   'crush',
#   'on',
#   'miranda'],
#  ['his', 'head', 'is', 'really', 'that', 'bald'],
#  ['yellow', 'for', '?'],
#  ['hahah'],
#  ['feeling', 'smooth', 'like', 'chrome'],
#  ['ew', 'traffic'],
#  ['downloading',
#   'songs',
#   'while',
#   'trying',
#   'to',
#   'sneak',
#   'a',
#   'lil',
#   'homework',
#   'in',
#   'too',
#   ',',
#   'which',
#   'should',
#   'be',
#   'my',
#   'main',
#   'priority',
#   'not',
#   'songs',
#   'lol'],
#  ['your', 'not', 'alone', '...', 'i', 'need', 'coffee', 'too', '.'],
#  ['sounds', 'like', 'me'],
#  ['bad',
#   'day',
#   'the',
#   'day',
#   'you',
#   'realize',
#   'what',
#   'mess',
#   'you',
#   '`',
#   've',
#   'put',
#   'me',
#   'through',
#   'will',
#   'be',
#   'one',
#   'of',
#   'the',
#   'happiest',
#   'days',
#   'of',
#   'my',
#   'life',
#   '...'],
#  ['i',
#   'hate',
#   'not',
#   'having',
#   'a',
#   'bike',
#   '...',
#   '.especially',
#   'mine',
#   '.'],
#  ['_nesmith'],
#  ['this', 'is', 'worse', 'than', 'taxes', '.'],
#  ['it', '`', 's', 'rocking', 'so', 'hard', 'i', 'love', 'the', 'song', ','],
#  ['happy',
#   'mother',
#   '`',
#   's',
#   'day',
#   'to',
#   'all',
#   'the',
#   'mothers',
#   'in',
#   'the',
#   'world',
#   '.'],
#  ['35mins',
#   'through',
#   'the',
#   '1hr',
#   '20mins',
#   'google',
#   'wave',
#   'demo',
#   ',',
#   'that',
#   'looks',
#   'a',
#   'lot',
#   'of',
#   'fun',
#   ',',
#   'would',
#   'love',
#   'to',
#   'test',
#   'it',
#   'though',
#   '.'],
#  ['listened',
#   'through',
#   'the',
#   'next',
#   'episode',
#   'of',
#   'joss',
#   '`',
#   'd',
#   '!'],
#  ['the',
#   'exception',
#   'for',
#   'a',
#   'short',
#   'dude',
#   ':',
#   'larenz',
#   'fineass',
#   'tate',
#   'yum'],
#  ['but', 'not', 'enough', 'dominic', 'monaghan', 'for', 'my', 'liking', '.'],
#  ['hopefully', 'we', 'will', 'be', 'free', 'soon', '.'],
#  ['yes', 'i', 'work', '6', 'to', '3', '...'],
#  ['they',
#   'eluded',
#   'to',
#   'something',
#   'brand',
#   'new',
#   'but',
#   'you',
#   'know',
#   'how',
#   'the',
#   'media',
#   'is'],
#  ['done',
#   'at',
#   'the',
#   'spa',
#   'now',
#   'meeting',
#   'vic',
#   'for',
#   'some',
#   'late',
#   'lunch',
#   '!'],
#  ['hope', 'everyone', 'has', 'a', 'blessed', 'day', '!'],
#  ['always', 'have', 'wanted', 'to', 'go', 'to', 'oz'],
#  ['thx'],
#  ['-', 'cool', '...', 'luv', 'it'],
#  ['that',
#   '`',
#   's',
#   'why',
#   'i',
#   'need',
#   'to',
#   'be',
#   'there',
#   '...',
#   'to',
#   'represent',
#   'the',
#   'blackberries'],
#  ['okay',
#   'so',
#   'i',
#   '`',
#   'm',
#   'dedicating',
#   'my',
#   '300th',
#   'tweet',
#   'to',
#   'the',
#   'fact',
#   'that',
#   'i',
#   '`',
#   'm',
#   'going',
#   'to',
#   'the',
#   'apple',
#   'store',
#   'because',
#   'there',
#   'is',
#   'a',
#   'huge',
#   'crack',
#   'on',
#   'the',
#   'glass',
#   'screen',
#   '!'],
#  ['if',
#   'only',
#   'we',
#   'could',
#   'ever',
#   'actually',
#   'be',
#   'allowed',
#   'to',
#   'stay',
#   'here',
#   'and',
#   'do',
#   'that'],
#  ['!'],
#  ['haha'],
#  ['yeah', 'i', 'was', 'thinking', 'about', 'that', ',', 'ahaha'],
#  ['google', 'ki', 'jai', 'ho'],
#  ['i',
#   '`',
#   'm',
#   'not',
#   'sleeping',
#   'at',
#   'all',
#   'until',
#   'accepts',
#   'my',
#   'appology'],
#  ['?'],
#  ['i', 'live', 'for', 'pain', ',', 'bring', 'it', 'on'],
#  ['okay',
#   ',',
#   'i',
#   '`',
#   'm',
#   'out',
#   'for',
#   'a',
#   'while',
#   'back',
#   'later',
#   '!'],
#  ['i', '`', 'm', 'a', 'newbie', 'follower'],
#  ['got', 'a', 'headache', 'now', '#', 'insanedefaults'],
#  ['first', 'time'],
#  ['?'],
#  ['going',
#   'to',
#   'shower',
#   'because',
#   'i',
#   'don',
#   '`',
#   't',
#   'want',
#   'to',
#   'smell',
#   'at',
#   'school',
#   'tomorrow'],
#  ['sigh', '...', 'you', 'know', 'i', 'am', '...'],
#  ['publishing',
#   'bug',
#   'fix',
#   'now',
#   ',',
#   'hopefully',
#   'new',
#   'beta',
#   'by',
#   'tomorrow'],
#  ['here',
#   'are',
#   '4',
#   'free',
#   'twitter',
#   'tools',
#   'will',
#   'get',
#   'you',
#   'followers'],
#  ['just',
#   'got',
#   'home',
#   'from',
#   'work',
#   '...',
#   '.',
#   'and',
#   'is',
#   'chugging',
#   'down',
#   'a',
#   'big',
#   'bottle',
#   'of',
#   'apple',
#   'juice',
#   '.'],
#  ['if',
#   'you',
#   'die',
#   'i',
#   'will',
#   'cry..',
#   'which',
#   'normally',
#   'leads',
#   'to',
#   'small',
#   'animals',
#   'getting',
#   'harmed'],
#  ['check', 'it', 'out', 'on', 'fb', 'soon', '!'],
#  ['it',
#   'was',
#   'only',
#   'once',
#   'for',
#   'my',
#   'big',
#   'brother',
#   '...',
#   'and',
#   'i',
#   '`',
#   'm',
#   'done',
#   'now'],
#  ['bad', 'news', ':', 'my', 'resistance', 'band', 'is', 'torn'],
#  ['well',
#   'good',
#   'morning',
#   'all',
#   ',',
#   'what',
#   'a',
#   'wonderful',
#   'day',
#   'in',
#   'the',
#   'neighborhood',
#   'thanks',
#   'for',
#   'all',
#   'those',
#   'that',
#   'are',
#   'now',
#   'following',
#   'another',
#   '60',
#   'this',
#   'morning'],
#  ['ftsk',
#   'and',
#   'mercy',
#   'mercedes',
#   'were',
#   'amazing',
#   'tonight..',
#   'as',
#   'always'],
#  ['hope', 'he', 'is', 'ok', '!'],
#  ['it', 'hurts', 'too', 'much', '...', 'seeing', 'him', 'every', 'day'],
#  ['are',
#   'none',
#   'of',
#   'you',
#   'old',
#   'enough',
#   'to',
#   'know',
#   'what',
#   'to',
#   'do',
#   'when',
#   'someone',
#   'says',
#   'crackerack',
#   '?'],
#  ['hell', 'yeah', '!'],
#  ['does', 'it', 'actually', 'have', 'ville', 'on', 'it', '?'],
#  ['!'],
#  ['i', 'love', 'alex', 'vixon'],
#  ['dindin',
#   'and',
#   'i',
#   'showed',
#   'up',
#   'in',
#   'matching',
#   'outfits',
#   ')',
#   'great',
#   'minds',
#   'think',
#   'alike',
#   ')',
#   'anyway',
#   ',',
#   'happy',
#   'birthday',
#   ',',
#   'ate',
#   'lara'],
#  ['just',
#   'woke',
#   'up',
#   'on',
#   'this',
#   'side',
#   'of',
#   'earth',
#   ',',
#   'so',
#   'wishes',
#   'are',
#   'bit',
#   'late'],
#  ['thank',
#   'you',
#   'for',
#   'teaching',
#   'me',
#   'values',
#   'and',
#   'to',
#   'be',
#   'a',
#   'better',
#   'person',
#   'each',
#   'day',
#   'i',
#   'love',
#   'so',
#   'much',
#   ',',
#   'you',
#   '`',
#   're',
#   'the',
#   'best',
#   'mum',
#   'in',
#   'the',
#   'world'],
#  ['!'],
#  ['*laughs*',
#   'i',
#   '`',
#   'm',
#   'glad',
#   'that',
#   'you',
#   'have',
#   'self',
#   'confidence',
#   '-',
#   'it',
#   '`',
#   's',
#   'a',
#   'wonderful',
#   'trait',
#   'to',
#   'have',
#   'i',
#   '`',
#   'll',
#   'applaud',
#   'extra',
#   'loud',
#   'for',
#   'it',
#   ',',
#   'okay',
#   '?'],
#  ['thanks'],
#  ['twittering', 'after', '2', 'days', '!'],
#  ['getting',
#   'ready',
#   'for',
#   'week',
#   'its',
#   'too',
#   'nice',
#   'today',
#   'to',
#   'be',
#   'stuck',
#   'inside',
#   'working',
#   '!'],
#  ['i', 'am', 'tres', 'depressed'],
#  ['painful', 'tum', ',', 'threw', 'up', ',', 'still', 'feel', 'sick', '.'],
#  ['i', 'love', 'my', 'mom', 'a', 'lot', 'still'],
#  ['i', '`', 'm', 'sorry', 'to', 'hear', 'that', '.'],
#  ['i',
#   'got',
#   'to',
#   'meet',
#   'him',
#   'a',
#   'few',
#   'years',
#   'ago',
#   ',',
#   'he',
#   'was',
#   'soooo',
#   'friendly',
#   '.'],
#  ['!'],
#  ['is', 'getting', 'the', 'hang', 'of', 'twitter', '.'],
#  ['you',
#   'know',
#   'your',
#   'neck',
#   'is',
#   'jacked',
#   'up',
#   'when',
#   'you',
#   'are',
#   'forced',
#   'to',
#   'pay',
#   'for',
#   'parking',
#   'bc',
#   'you',
#   'can',
#   '`',
#   't',
#   'turn',
#   'you',
#   'head',
#   'to',
#   'parallel',
#   'park',
#   'in',
#   'the',
#   'free',
#   'spaces',
#   '...'],
#  [':'],
#  ['going',
#   'to',
#   'miss',
#   'my',
#   'roomie',
#   '...',
#   'we',
#   'will',
#   'no',
#   'longer',
#   'be',
#   'roomies',
#   'starting',
#   'tomorrow'],
#  ['bathing',
#   'with',
#   'two',
#   'little',
#   'angels',
#   ',',
#   'keyla',
#   'and',
#   'janice',
#   '.'],
#  ['yep',
#   ',',
#   'finished',
#   ',',
#   'chocked',
#   'full',
#   'of',
#   'spelling',
#   'and',
#   'grammatical',
#   'errors',
#   ',',
#   'but',
#   'i',
#   '`',
#   'm',
#   'cleaning',
#   'it',
#   'up',
#   'tomorrow',
#   'and',
#   'popping',
#   'it',
#   'up',
#   'hehe'],
#  ['i',
#   'always',
#   'remember',
#   'my',
#   'bd',
#   'but',
#   'i',
#   'can',
#   'never',
#   'remember',
#   'what',
#   'date',
#   'or',
#   'even',
#   'day',
#   'it',
#   'is'],
#  ['family', 'is', 'here', ',', 'hanging', 'with', 'them'],
#  ['then',
#   'doing',
#   'the',
#   'dishes',
#   'and',
#   'tanning',
#   '...',
#   'it',
#   '`',
#   's',
#   'gorgeous',
#   'out',
#   '!'],
#  ['i', '`', 'm', 'worried', 'about', 'you'],
#  ['im',
#   'not',
#   'bannished',
#   '...',
#   'but',
#   'i',
#   'am',
#   'at',
#   'work',
#   'till',
#   '6'],
#  ['right',
#   'now',
#   ',',
#   'i',
#   '`',
#   'm',
#   'going',
#   'to',
#   'go',
#   'see',
#   'wolverine',
#   '.'],
#  ['red',
#   'top',
#   'tabloids',
#   ',',
#   'build',
#   'em',
#   'up',
#   ',',
#   'knock',
#   'em',
#   'down'],
#  ['tonight', 'in', 'party', 'w/', 'my', 'girls', '(', 'minus', 'vita', ')'],
#  ['why',
#   'not',
#   'now',
#   'you',
#   'made',
#   'me',
#   'sad',
#   'i',
#   'thought',
#   'you',
#   '`',
#   'd',
#   'be',
#   'jumping',
#   'for',
#   'joy'],
#  ['simple', 'my'],
#  ['missy',
#   'is',
#   'now',
#   'an',
#   'adult',
#   'and',
#   'a',
#   'pretty',
#   'little',
#   'kitty',
#   ',',
#   'but',
#   'batty',
#   'is',
#   'in',
#   'kitten',
#   'heaven',
#   'now'],
#  ['i', 'saw', 'the', 'play', 'of', 'it', 'here', ',', 'it', 'was', 'amazing'],
#  ['_',
#   'i',
#   'am',
#   'glad',
#   'to',
#   'break',
#   'my',
#   'twitter',
#   'virginity',
#   'with',
#   'you',
#   'two',
#   '.'],
#  ['i', 'have', 'missed', 'them'],
#  ['bound',
#   'to',
#   'be',
#   'a',
#   'few',
#   'bad',
#   'eggs',
#   'though',
#   ',',
#   'but',
#   'they',
#   'will',
#   'soon',
#   'learn',
#   '.'],
#  ['finally', '.'],
#  ['i', 'know', 'it', 'was', 'worth', 'a', 'shot', ',', 'though', '!'],
#  ['twitter', 'seems', 'much', 'better'],
#  ['i', '`', 'm', 'stuck', '.'],
#  ['dustbin', 'baby', 'on', 'at', '11.30', 'can', 'not', 'wait', 'x'],
#  ['x'],
#  ['it',
#   'looks',
#   'like',
#   'the',
#   'office',
#   'tv',
#   'does',
#   'get',
#   'mlb',
#   'network',
#   '...',
#   'and',
#   'it',
#   'looks',
#   'like',
#   'mlbn',
#   'will',
#   'not',
#   'be',
#   'televising',
#   'the',
#   'det/bal',
#   'game',
#   'today',
#   '#',
#   'wieters'],
#  ['i',
#   'shall',
#   'now',
#   'indulge',
#   'in',
#   'my',
#   'cupcakes',
#   'from',
#   'magnolia',
#   'bakery',
#   '.'],
#  ['definitely', 'pinched', 'a', 'nerve', '.'],
#  ['exhausting', '!'],
#  ['i',
#   'was',
#   'going',
#   'to',
#   'go',
#   'on',
#   'sunday',
#   ',',
#   'but',
#   'now',
#   'i',
#   '`',
#   've',
#   'got',
#   'too',
#   'much',
#   'going',
#   'on',
#   'that',
#   'weekend'],
#  ['!'],
#  ['ohh',
#   'my',
#   'tooth',
#   'is',
#   'hurts',
#   'ohh',
#   'im',
#   'sad',
#   'it',
#   'very',
#   'hurts'],
#  ['and', 'to', 'my', 'others', ':', 'feelin', 'the', 'love'],
#  ['u',
#   'think',
#   'u',
#   'have',
#   'bills',
#   'ha',
#   '!',
#   'ii',
#   'just',
#   'finished',
#   'paying',
#   'mine',
#   'that',
#   '`',
#   's',
#   'y',
#   'i',
#   '`',
#   'm',
#   'broke'],
#  ['!'],
#  ['planning',
#   'the',
#   'tet',
#   'outing',
#   'to',
#   'marwell',
#   'though',
#   '...',
#   'good',
#   'times'],
#  ['mcfly',
#   'gig',
#   'last',
#   'nightt',
#   'omg',
#   'it',
#   'was',
#   'amazin',
#   'didnt',
#   'sit',
#   'down',
#   'through',
#   'the',
#   'whole',
#   'thing',
#   'mcfly',
#   'did',
#   'you',
#   'see',
#   'me',
#   'and',
#   'ma',
#   'best',
#   'mate',
#   'we',
#   'were',
#   'in',
#   'tutus'],
#  ['i', 'thought', 'life', 'postr01', 'was', 'meant', 'to', 'be', 'relaxing'],
#  ['there', '!'],
#  ['?', '..'],
#  ['whens', 'the', 'sway', 'sway', 'winner', 'announced', '?'],
#  ['k', 'will', 'check', 'it', 'out', '...'],
#  ['doing', 'pretty', 'well', ',', 'up', 'and', 'wide', 'awake'],
#  ['but', 'have', 'to', 'keep', 'writing..', 'booo', 'whoo', '!'],
#  ['i', 'miss', 'daddy', 'and', 'mommy'],
#  ['he',
#   'doesn',
#   '`',
#   't',
#   'want',
#   'to',
#   'go',
#   'outside',
#   'and',
#   'when',
#   'we',
#   'did',
#   ',',
#   'he',
#   'play',
#   'half-heartedly',
#   '.'],
#  ['i',
#   'just',
#   'realized',
#   'that',
#   'i',
#   'can',
#   '`',
#   't',
#   'forward',
#   'text',
#   'msgs',
#   'with',
#   'my',
#   'iphone',
#   '.'],
#  ['my',
#   'frist',
#   'post',
#   '...',
#   'off',
#   'to',
#   'find',
#   'a',
#   'new',
#   'car',
#   'for',
#   'my',
#   'parents',
#   ',',
#   'exciting',
#   '!'],
#  ['must', 'investigate', '!'],
#  ['seriously',
#   'bored',
#   'without',
#   'anyone',
#   'to',
#   'talk',
#   'to',
#   '...',
#   'but',
#   'not',
#   'tired',
#   'enough',
#   'for',
#   'sleep'],
#  ['please', 'help', 'me', 'find', 'a', 'good', 'home', '.'],
#  ['it',
#   '`',
#   's',
#   'a',
#   'peter',
#   '&',
#   'gordon',
#   'morning',
#   '-',
#   '>',
#   'and',
#   'i',
#   ',',
#   'go',
#   'to',
#   'pieces',
#   'and',
#   'i',
#   'wan',
#   'na',
#   'hide',
#   '/',
#   'go',
#   'to',
#   'pieces',
#   'and',
#   'i',
#   'almost',
#   'die',
#   '/',
#   'ever',
#   '...',
#   '?'],
#  ['ok',
#   'so',
#   'i',
#   '`',
#   've',
#   'now',
#   'got',
#   'a',
#   'bit',
#   'of',
#   'a',
#   'bad',
#   'back',
#   'after',
#   'lifting',
#   'all',
#   'drum',
#   'hardware',
#   'into',
#   'my',
#   'car',
#   'downer',
#   '.'],
#  ['that', 'one', 'threw', 'me', 'off', '.'],
#  ['oh', 'nice', 'going', '!'],
#  ['working', 'all', 'weekend'],
#  ['gon',
#   'na',
#   'celebrate',
#   'mothers',
#   'day',
#   'with',
#   'the',
#   'family',
#   'but',
#   'gon',
#   'na',
#   'start',
#   'the',
#   'partying',
#   'tonite'],
#  ['i', 'agree', 'with', 'you', '!'],
#  ['am', 'hopeless', 'at', 'everything', 'else'],
#  ['90',
#   'degrees',
#   ',',
#   'gross',
#   'skies',
#   ',',
#   'and',
#   'thunderstorms',
#   '...',
#   'perfect',
#   'match',
#   'for',
#   'my',
#   'mood',
#   'lol'],
#  ['_2nd', 'aww', 'thanks', '!'],
#  ['sorry', 'rb', 'is', 'on', 'ps3', 'for', 'me'],
#  ['but', 'they', 'were', 'too', 'big'],
#  ['i',
#   'just',
#   'stuck',
#   'my',
#   'finger',
#   'down',
#   'my',
#   'throat',
#   'and',
#   'there',
#   'are',
#   'a',
#   'bunch',
#   'of',
#   'bumps',
#   'on',
#   'my',
#   'tongue',
#   '&',
#   'throat',
#   '.'],
#  ['dang', 'last', 'url', 'went', 'down', '?'],
#  ['ohoh',
#   'i',
#   'missed',
#   'all',
#   'ur',
#   'tweets',
#   'im',
#   'gon',
#   'na',
#   'have',
#   'to',
#   'stay',
#   'awake',
#   'all',
#   'night',
#   'to',
#   'see',
#   'the',
#   'announcement',
#   'now',
#   ',',
#   '****',
#   'time',
#   'difference'],
#  ['you',
#   'were',
#   'one',
#   'of',
#   'the',
#   'ones',
#   'i',
#   'thought',
#   'i',
#   '`',
#   'd',
#   'drag',
#   'back',
#   'lol'],
#  ['she', '`', 's', 'moving', 'to', 'nyc'],
#  ['this', 'is', 'sooo', 'crazy', 'i', 'have', 'fever..'],
#  ['not', 'fair'],
#  ['i', 'think', 'i', 'need', 'some', 'new', 'friends'],
#  ['see', 'ya', 'there', '!'],
#  ['please', 'review', 'sunehre', 'ad', 'placement'],
#  ['aww', 'you', 'loooove', 'me'],
#  ['<', '/3'],
#  ['awesome', 'lucky', 'you'],
#  ['ps', ':', 'send', 'me', 'direct', 'messages', 'telling..', 'haha'],
#  ['haha', 'im', 'jewish', ',', 'i', 'love', 'that', 'one'],
#  ['!'],
#  ['no', 'fun', 'this', 'weekend', '.'],
#  ['think',
#   'u',
#   'told',
#   'me',
#   'b4',
#   '...',
#   'i',
#   'might',
#   'have',
#   'an',
#   'app',
#   'for',
#   'u'],
#  ['mine', 'is', 'the', 'same', 'way'],
#  ['comes', 'home', 'in', 'two', 'days'],
#  ['it', 'didn', '`', 't', 'come', 'with', 'one', '...'],
#  ['cant', 'wait', 'to', 'see', 'my', 'boy', 'tomorrow'],
#  ['getting', 'my', 'molar', 'pulled/root', 'canal', '.'],
#  ['aww', 'i', 'miss', 'driving', 'down', 'elmwood'],
#  ['i', 'love', 'my', 'baby', 'for', 'taking', 'me'],
#  ['version',
#   '2',
#   'of',
#   'our',
#   'live',
#   ',',
#   'interactive',
#   'trans-siberian',
#   'ticket',
#   'planner',
#   'is',
#   'launched',
#   ':',
#   '-',
#   'its',
#   'very',
#   'cool'],
#  ['_30439', 'i', 'really', 'wish', 'i', 'could', 'go', '!'],
#  ['yeah',
#   'real',
#   'hard',
#   ',',
#   'but',
#   'i',
#   'know',
#   'you',
#   '`',
#   'll',
#   'get',
#   'by',
#   'with',
#   'it',
#   '...',
#   'smile'],
#  ['i',
#   '`',
#   'm',
#   '25',
#   'in',
#   'december',
#   'that',
#   '`',
#   's',
#   'not',
#   'good',
#   'at',
#   'all',
#   'next',
#   'big',
#   'birthday',
#   'is',
#   '30',
#   'after',
#   '21',
#   'it',
#   'flys',
#   'by',
#   'for',
#   'sure'],
#  ['!'],
#  ['happy', 'mother', '`', 's', 'day', '!'],
#  ['i',
#   'make',
#   'that',
#   'same',
#   'face',
#   'when',
#   'i',
#   'get',
#   'home',
#   'and',
#   'your',
#   'mom',
#   'is',
#   'watching',
#   'soaps',
#   '.'],
#  ['i', 'have', 'to', 'go', 'to', 'work', 'now', '.'],
#  ['i',
#   'can',
#   '`',
#   't',
#   'believe',
#   'you',
#   'went',
#   'and',
#   'got',
#   'boba',
#   'without',
#   'me',
#   '.'],
#  ['and', 'to', 'you', 'too', ',', 'how', 'are', 'you', 'today', '?'],
#  ['we',
#   'didn',
#   '`',
#   't',
#   'make',
#   'plans',
#   'because',
#   'our',
#   'arrival',
#   'time',
#   'was',
#   'so',
#   'up',
#   'in',
#   'the',
#   'air',
#   '.'],
#  ['19', 'days', 'and', 'counting'],
#  ['no', 'charades', 'for', 'me', '.'],
#  ['brainfreeze'],
#  ['when',
#   'you',
#   'use',
#   'twitpic',
#   '(',
#   'integrated',
#   ')',
#   'it',
#   'doesn',
#   '`',
#   't',
#   'subtract',
#   'the',
#   'pic',
#   'url',
#   'from',
#   'the',
#   '140',
#   'character',
#   'limit'],
#  ['my', 'sunburn', 'is', 'peeling', ','],
#  ['perky',
#   'purple',
#   'nail',
#   'polish',
#   'isn',
#   '`',
#   't',
#   'as',
#   'perky',
#   'when',
#   'its',
#   'chipped'],
#  ['i',
#   'can',
#   'no',
#   'longer',
#   'vandalize',
#   'that',
#   'door',
#   ',',
#   'without',
#   'being',
#   'caught',
#   '.'],
#  ['i',
#   'thought',
#   'it',
#   'was',
#   'ill',
#   'at',
#   'first',
#   'now',
#   'i',
#   'don',
#   '`',
#   't',
#   'have',
#   'no',
#   'one',
#   'to',
#   'cuddle',
#   'with',
#   '...'],
#  ['i', 'hate', 'the', 'dentist'],
#  ['nothing',
#   'aimed',
#   'at',
#   'you',
#   ',',
#   'just',
#   'joining',
#   'in',
#   '...',
#   'sorry'],
#  ['cell', 'is', 'dying'],
#  ['qood', 'morninq'],
#  ['and',
#   'listening',
#   'to',
#   '`',
#   'a',
#   'little',
#   'respect',
#   '`',
#   'by',
#   'erasure',
#   'aaaaaah',
#   '.'],
#  ['needs', 'more', 'followers'],
#  ['i', 'wish', 'i', 'could', 'get', 'my', 'nails', 'done', 'stupid', 'job'],
#  ['the',
#   'little',
#   'wormy',
#   'from',
#   'labyrinth',
#   'sadly',
#   'passed',
#   'away',
#   'today',
#   'but',
#   'its',
#   'ok',
#   'as',
#   'hes',
#   'still',
#   'around',
#   'in',
#   'a',
#   'happy',
#   'ghost',
#   'form',
#   'aww'],
#  ['the',
#   'no',
#   'pants',
#   'idea',
#   'could',
#   'be',
#   'the',
#   'new',
#   'attempt',
#   'world-wide',
#   'to',
#   'attract',
#   'business',
#   'back',
#   'to',
#   'the',
#   'airlines',
#   '.'],
#  ['have', 'a', 'good', 'one'],
#  ['yep',
#   'infact',
#   'she',
#   'is',
#   'popular',
#   ',',
#   'miss',
#   'india',
#   '99',
#   ',',
#   'talented',
#   'film',
#   'actress',
#   '...',
#   '.',
#   'and',
#   'lot',
#   'more'],
#  ['dosen', '`', 't', 'want', 'to', 'go', 'to', 'work', 'tomorrow'],
#  ['his', 'voice', 'is', 'great', '.'],
#  ['[',
#   '-o',
#   ']',
#   'i',
#   'wish',
#   'the',
#   'birthday',
#   'massacre',
#   'would',
#   'come',
#   'to',
#   'australia',
#   'i',
#   'think',
#   'they',
#   'said',
#   'they',
#   '`',
#   're',
#   'thinking',
#   'about',
#   'it',
#   'tho..'],
#  ['was', 'hoping', 'to', 'go', 'to', 'red', 'lobster', 'this', 'weekend'],
#  ['hehe',
#   'i',
#   'mean',
#   'ur',
#   'ssoo',
#   'lucky',
#   'to',
#   'have',
#   'the',
#   'address',
#   '!'],
#  ['i',
#   'sure',
#   'do',
#   'hope',
#   'it',
#   'becomes',
#   '4:20',
#   'this',
#   'afternoon',
#   '...'],
#  ['congrats', '!'],
#  ['he',
#   'jumped',
#   'off',
#   'the',
#   'table',
#   'searching',
#   'for',
#   'a',
#   'new',
#   'phone',
#   '...'],
#  ['thanks',
#   'for',
#   'being',
#   'in',
#   'my',
#   'life',
#   '-',
#   'you',
#   'are',
#   'such',
#   'amazing',
#   'people',
#   '!'],
#  ['tamlyn', 'wishes', 'she', 'was', 'as', 'cool', 'as', 'my', 'sock', 'draw'],
#  ['so',
#   'no',
#   'rice',
#   'or',
#   'crusty',
#   'bread',
#   'with',
#   'the',
#   'chili',
#   '...',
#   '.',
#   'aawww'],
#  ['we',
#   'are',
#   'of',
#   'like',
#   'minds',
#   'this',
#   'evening',
#   ',',
#   'my',
#   'dear',
#   '!'],
#  ['!'],
#  ['if',
#   'that',
#   'makes',
#   'me',
#   'typically',
#   'english',
#   'then',
#   'so',
#   'be',
#   'it'],
#  ['a', 'mouth', 'for', 'sure'],
#  ['but',
#   'i',
#   'went',
#   'to',
#   'my',
#   'highschool',
#   'at',
#   '8.00',
#   'am',
#   'to',
#   'make',
#   'some',
#   'homework',
#   'with',
#   'a',
#   'friend'],
#  ['with', 'lemon', 'and', 'sugar', 'thanks', '!'],
#  ['si',
#   ',',
#   'no',
#   'bueno',
#   'i',
#   'guess',
#   'i',
#   'just',
#   'don',
#   '`',
#   't',
#   'entertain',
#   'him',
#   ':',
#   '/'],
#  ['i',
#   '`',
#   'm',
#   'so',
#   'hunrgy',
#   'right',
#   'now',
#   'and',
#   'these',
#   'heels',
#   'kill',
#   'me',
#   'i',
#   'can',
#   'hardly',
#   'walk',
#   'in',
#   'them'],
#  ['so', 'much', 'for', 'technology'],
#  ['good',
#   'to',
#   'know',
#   'more',
#   'than',
#   'one',
#   'person',
#   'in',
#   'this',
#   'big',
#   'wide',
#   'world',
#   'likes',
#   'fishies',
#   '.'],
#  ['-', 'poor', 'tony'],
#  ['goodmorning'],
#  ['i',
#   'don',
#   '`',
#   't',
#   'really',
#   'feel',
#   'like',
#   'working',
#   'right',
#   'now',
#   '.'],
#  ['much', 'love', 'to', 'you', ',', 'too', '.'],
#  ['went', 'back', 'for', 'a', 'picture', 'and', 'it', 'was', 'gone'],
#  ['dogs', 'are', 'the', 'best'],
#  ['no',
#   'waterfront',
#   'anymore',
#   'faccia',
#   'luna',
#   'and',
#   'clarendon',
#   'will',
#   'have',
#   'to',
#   'do'],
#  ['happy',
#   'mothers',
#   'day',
#   'to',
#   'all',
#   'the',
#   'wonderful',
#   'mothers',
#   'out',
#   'there'],
#  ['slipped',
#   'up',
#   'and',
#   'caught',
#   'the',
#   'flu',
#   'feeling',
#   'like',
#   'poop',
#   '!'],
#  ['5+47days', 'til', 'mcfly', ',', 'im', 'so', 'excited', '(', 'l', ')'],
#  ['ok',
#   '...',
#   'the',
#   'passengers',
#   '...',
#   'no',
#   'one',
#   'is',
#   'alive',
#   '...',
#   'they',
#   '`',
#   're',
#   'all',
#   'dead',
#   '...',
#   'you',
#   'just',
#   'don',
#   '`',
#   't',
#   'know',
#   'it',
#   'til',
#   'the',
#   'end',
#   '...',
#   'then',
#   'you',
#   'cry',
#   '...'],
#  ['sigh', '...', '.', 'i', '`', 'm', 'such', 'a', 'g', 'reader', 'newb', '.'],
#  ['seems', 'like', 'these', 'are', 'the', 'only', '2', 'styles', 'she', 'has'],
#  ['lord', 'knows', 'i', 'need', 'it', '.'],
#  ['aaaaaw', 'i', 'want', 'to', 'live', 'in', 'the', 'usa'],
#  ['morning', 'tweeple'],
#  ['!'],
#  ['now',
#   'you',
#   'only',
#   'have',
#   '2',
#   'hours',
#   'to',
#   'sleep',
#   '...',
#   '-',
#   'rest',
#   'if',
#   'you',
#   'need',
#   'it',
#   '.'],
#  ['did', 'i', 'mention', 'i', 'love', 'the', 'new', 'photo', '!'],
#  ['someone', 'hang', 'out', 'with', 'me'],
#  ['is',
#   'heading',
#   'home',
#   'from',
#   'foot',
#   'surgery',
#   'and',
#   'wishing',
#   'she',
#   'had',
#   'a',
#   'boyfriend',
#   'to',
#   'come',
#   'over',
#   'and',
#   'cuddle',
#   'with'],
#  ['concert',
#   'tonight',
#   'chackin',
#   'out',
#   'and',
#   'not',
#   'coming',
#   'tomorrow',
#   '!'],
#  ['i', 'thought', 'you', 'were', 'coming', 'back', 'today', '...', '.'],
#  ['lol', 'dammit', 'well', 'then', 'next', 'time', 'then'],
#  ['just', 'don', '`', 't', 'ever', 'forget', 'me'],
#  ['still', 'jealous'],
#  ['-',
#   'me',
#   'at',
#   'forever',
#   '21',
#   'ethan',
#   'couldn',
#   '`',
#   't',
#   'be',
#   'there'],
#  [':', '**-', '('],
#  ['(', ':'],
#  ['bella'],
#  ['looks', 'good', 'to', 'me'],
#  ['there',
#   'are',
#   'people',
#   'and',
#   'then',
#   'there',
#   'are',
#   'pencils',
#   'some',
#   'are',
#   'sharp',
#   ',',
#   'some',
#   'are',
#   'not',
#   'and',
#   'some',
#   'can',
#   'be',
#   'sharpened',
#   'my',
#   'pencil',
#   'philosophy',
#   '...',
#   '..'],
#  ['well', ',', '15', 'mins', 'until', 'tomorrow', '!'],
#  ['let', '`', 's', 'go', 'to', 'paris'],
#  ['you',
#   'know',
#   'you',
#   'want',
#   'to',
#   'come',
#   'keep',
#   'me',
#   'company',
#   'whilst',
#   'mum',
#   '`',
#   's',
#   'at',
#   'her',
#   'friends',
#   'for',
#   'the',
#   'night',
#   'it',
#   '`',
#   's',
#   'such',
#   'a',
#   'nice',
#   'evening',
#   '!'],
#  ['cooking',
#   'with',
#   'my',
#   'dad',
#   'having',
#   'lots',
#   'of',
#   'fun',
#   'in',
#   'the',
#   'kitchen',
#   'together'],
#  ['bouncing', 'rush', 'makes', 'me', 'feel', 'nauseous'],
#  ['lovely', 'day', 'for', 'it'],
#  ['playing', 'singstar', 'without', 'my', 'fave', 'duetter'],
#  ['i',
#   '`',
#   'm',
#   'such',
#   'a',
#   'cereal',
#   'nut',
#   ',',
#   'i',
#   'think',
#   'i',
#   'like',
#   'every',
#   'kind',
#   'available',
#   '.'],
#  ['that',
#   '`',
#   's',
#   'just',
#   'weird',
#   '...',
#   ':',
#   '\\',
#   'oh',
#   ',',
#   'and',
#   'what',
#   'was',
#   'it',
#   'you',
#   'were',
#   'drawing',
#   'for',
#   'me',
#   '?'],
#  ['just',
#   'woke',
#   'up',
#   ':',
#   'o',
#   'mums',
#   'singing',
#   'to',
#   'her',
#   'new',
#   'gn',
#   '`',
#   'r',
#   'cd',
#   'replacement',
#   'i',
#   'bought',
#   'because',
#   'im',
#   'a',
#   'good',
#   'daughter'],
#  ['!'],
#  ['thats', 'ok', ',', 'u2', 'on', 'the', 'radio', 'alwas', 'helps', '.'],
#  ['my',
#   'street',
#   'fighter',
#   'iv',
#   'skills',
#   'are',
#   'lacking',
#   ',',
#   'can',
#   '`',
#   't',
#   'beat',
#   'seth',
#   'on',
#   'easy',
#   '.'],
#  ['fil', '461', 'with', 'cool', 'people', 'like', 'me'],
#  ['hopefully', 'it', 'won', '`', 't', 'get', 'rained', 'out'],
#  ['i',
#   'think',
#   'it',
#   '`',
#   's',
#   'under',
#   'a',
#   'honeymoon',
#   'by',
#   'the',
#   'good',
#   'life',
#   '--',
#   'either',
#   'that',
#   'or',
#   'it',
#   '`',
#   's',
#   'under',
#   'a',
#   'honey',
#   'moon',
#   'by',
#   'joseph',
#   'arthur',
#   '.'],
#  ['my',
#   'son',
#   'got',
#   'stung',
#   'by',
#   'a',
#   'bug',
#   'for',
#   'the',
#   'first',
#   'time',
#   'his',
#   'little',
#   'finger',
#   'is',
#   'slightly',
#   'swollen',
#   '.'],
#  ['it',
#   'was',
#   'hours',
#   'ago',
#   'i',
#   'came',
#   'in',
#   '...',
#   '.',
#   'and',
#   'it',
#   '`',
#   's',
#   'only',
#   'now',
#   'i',
#   'realised',
#   'when',
#   'i',
#   'went',
#   'to',
#   'buy',
#   'something',
#   'online'],
#  ['oh',
#   'just',
#   'referring',
#   'to',
#   'our',
#   'lil',
#   'exchange',
#   'on',
#   'lj',
#   'with',
#   'regards',
#   'to',
#   'twitter',
#   'archive',
#   'postings',
#   '.'],
#  ['don', '`', 't', 'act', 'like', 'u', 'don', '`', 't', 'know', '.'],
#  ['hope', 'you', 'have', 'the', 'best', 'day', 'ever'],
#  ['i', '`', 'm', 'scared', 'of', 'him'],
#  ['i',
#   '`',
#   'm',
#   'missing',
#   'crab',
#   'legs',
#   'and',
#   'attending',
#   'my',
#   'going',
#   'away',
#   'instead',
#   '!'],
#  ['hicks', 'are', 'mean', '!'],
#  ['gettn',
#   'ready',
#   'to',
#   'take',
#   'a',
#   'trip',
#   'to',
#   'jersey',
#   'my',
#   'dad',
#   '`',
#   's',
#   'not',
#   'doing',
#   'so',
#   'good',
#   ',',
#   'he',
#   'needs',
#   'a',
#   'new',
#   'heart~whoeva',
#   'see',
#   '`',
#   's',
#   'this',
#   'please',
#   'say',
#   'a',
#   'prayer',
#   'for',
#   'my',
#   'dad'],
#  ['back',
#   'soon',
#   ',',
#   'need',
#   'to',
#   'run',
#   'to',
#   'the',
#   'shops',
#   'and',
#   'cut',
#   'the',
#   'grass'],
#  ['random', '.'],
#  ['missing', 'nathan'],
#  ['thats', 'another', 'sponsor'],
#  ['and',
#   'most',
#   'of',
#   'us',
#   'are',
#   'going',
#   'to',
#   'be',
#   'stuck',
#   'in',
#   'an',
#   'office',
#   ',',
#   'some',
#   'without',
#   'windows'],
#  ['should', 'make', 'you', 'proud'],
#  ['sorry', ',', 'we', '`', 'll', 'try', 'to', 'keep', 'it', 'down', '.'],
#  ['doing', 'hw'],
#  ['according',
#   'to',
#   ',',
#   'a',
#   'quarter',
#   'of',
#   'families',
#   'under',
#   'six',
#   'live',
#   'in',
#   'poverty',
#   '.'],
#  ['the', 'plan', 'to', 'not', 'spend', 'money', 'is', 'not', 'going', 'well'],
#  ['uploading', 'all', 'my', 'bamboozle', 'pictures', 'of', 'facebook'],
#  ['booo'],
#  ['i', 'miss', 'it', 'there', '.'],
#  ['woke', 'up', ',', 'i', 'wan', 'na', 'stay', 'in', 'my', 'bed'],
#  ['but',
#   'my',
#   'bday',
#   'is',
#   'june',
#   '19..',
#   'this',
#   'is',
#   'wack',
#   '...',
#   'and',
#   'ihavent',
#   'seen',
#   'any',
#   'promotions',
#   'for',
#   'my',
#   'bday',
#   'party',
#   'someone',
#   'better',
#   'finagle',
#   'this',
#   'asap',
#   '!'],
#  ['it',
#   'would',
#   'be',
#   'great',
#   'if',
#   'those',
#   'vips',
#   'were',
#   'for',
#   'some',
#   'acts',
#   'i',
#   '`',
#   'd',
#   'enjoy',
#   'seeing',
#   ',',
#   'but',
#   'noooo',
#   '.'],
#  ['i', 'hate', 'my', 'commute', 'sometimes'],
#  ['workin',
#   'a',
#   'long',
#   'day',
#   'today',
#   '...',
#   'hopefully',
#   'i',
#   'can',
#   'make',
#   'some',
#   'good',
#   'tips'],
#  ['but',
#   'it',
#   'all',
#   'went',
#   'too',
#   'quick',
#   'and',
#   'there',
#   'wasn',
#   '`',
#   't',
#   'a',
#   'chance',
#   'lol'],
#  ['maybe', 'i', '`', 'm', 'not', 'ready', 'to', 'rock'],
#  ['thanks', 'for', 'the', 'support'],
#  ['there',
#   '`',
#   's',
#   'really',
#   'no',
#   'android',
#   'twitter',
#   'app',
#   'of',
#   'tweetie',
#   '`',
#   's',
#   'calibre'],
#  ['had',
#   'a',
#   'good',
#   'day',
#   'driving',
#   'up',
#   'mountains',
#   ',',
#   'visiting',
#   'katie',
#   ',',
#   'eating',
#   'chips',
#   '&',
#   'fudge',
#   'and',
#   'stocking',
#   'up',
#   'on',
#   'lovely',
#   'smelling',
#   'soaps'],
#  ['nyappy', 'mother', '`', 's', 'day', 'to', 'your', 'mom', '`', 's', '.'],
#  ['yeah',
#   '...',
#   '.',
#   'and',
#   'im',
#   'gon',
#   'na',
#   'take',
#   'ur',
#   'picture',
#   'off',
#   'my',
#   'ipod',
#   'baby..'],
#  ['my',
#   'dogs',
#   'massacred',
#   'baby',
#   'bunnies',
#   'and',
#   'my',
#   'brother',
#   'and',
#   'i',
#   'got',
#   'out',
#   'the',
#   'bb',
#   'gun',
#   '...'],
#  ['lol',
#   'same',
#   'here',
#   '...',
#   '.wish',
#   'there',
#   'was',
#   'a',
#   'way',
#   'to',
#   'microsize',
#   'everything',
#   '...',
#   'lol'],
#  ['organization',
#   '...',
#   'itil',
#   ',',
#   'forget',
#   'about',
#   'people',
#   '(',
#   'and',
#   'so',
#   'they',
#   'fail',
#   ')',
#   'preaching',
#   'to',
#   'the',
#   'converted',
#   'it',
#   'is',
#   'the',
#   'people'],
#  ['_libertine', 'um', ',', 'glad', 'you', 'enjoyed', 'it', '...'],
#  ['already',
#   'packed',
#   'and',
#   'ready',
#   'to',
#   'head',
#   'home',
#   'tomorrow',
#   'do',
#   'we',
#   'have',
#   'to',
#   'go',
#   'home',
#   '?'],
#  ['!'],
#  ['tomorrow', 'will', 'be', 'tough', '!'],
#  ['i', 'miss', 'her', 'alot', 'and', 'its', 'only', 'been', 'one', 'day'],
#  ['i', '`', 'm', 'glad', 'it', 'was', 'successful'],
#  ['thanks', 'for', 'sharing', 'that'],
#  ['you',
#   'should',
#   'say',
#   'mlia',
#   'instead',
#   'of',
#   'fml',
#   'i',
#   'hope',
#   'you',
#   'find',
#   'it',
#   'soon'],
#  ['garden',
#   'going',
#   'well',
#   ',',
#   'almost',
#   'all',
#   'the',
#   'corn',
#   'and',
#   'peas',
#   'are',
#   'up',
#   ',',
#   'no',
#   'onions',
#   'or',
#   'beets',
#   'up',
#   'yet',
#   'though',
#   '.'],
#  ['so', '...', 'bored', 'now'],
#  ['even',
#   'though',
#   'i',
#   '`',
#   'm',
#   'wearing',
#   'dirty',
#   'clothes',
#   'i',
#   'love',
#   'two',
#   'and',
#   'a',
#   'half',
#   'men',
#   '-',
#   'it',
#   '`',
#   's',
#   'amazing',
#   '!'],
#  ['yes', 'i', 'have', 'read', 'them', 'many', 'times', '.'],
#  ['cuz', 'you', 'play', 'a', 'grown', 'up', 'on', 'twitter', '?'],
#  ['i', 'am', 'living', 'in', 'ignorance'],
#  ['nope',
#   '...',
#   'it',
#   'is',
#   'telling',
#   'you',
#   'that',
#   'you',
#   'want',
#   'cameo',
#   'creams'],
#  ['awwww', 'we', '`', 're', 'gon', 'na', 'miss', 'you', '!'],
#  ['we',
#   'quite',
#   'like',
#   'worthing',
#   'its',
#   'a',
#   'relaxing',
#   'place',
#   'with',
#   'nice',
#   'coffee',
#   'shops',
#   'and',
#   'fresh',
#   'air..',
#   'and',
#   'not',
#   'too',
#   'many',
#   'oiks'],
#  ['what', 'kind', 'of', 'spock', 'is', 'that', '!'],
#  ['i', 'had', 'fun', 'with', 'and', 'this', 'evening', '!'],
#  ['sorry', 'to', 'answer', 'like', '100', 'years', 'later'],
#  ['sigh',
#   ',',
#   'my',
#   'sisters',
#   'bein',
#   'strange..',
#   'she',
#   'came',
#   'all',
#   'the',
#   'way',
#   'from',
#   'copenhagen',
#   'to',
#   'london',
#   ',',
#   'and',
#   'now',
#   'her',
#   'phones',
#   'turned',
#   'off..',
#   'i',
#   'wan',
#   'na',
#   'see',
#   'her',
#   'dammit'],
#  ['it', 'was', 'amazing'],
#  ['smh'],
#  ['i',
#   '`',
# ...
#   '#',
#   'jottonia',
#   'looks',
#   'good',
#   'too'],
#  ['!'],
#  ['coooooooool',
#   '...',
#   'dooooooooown',
#   '...',
#   'patience',
#   '...',
#   'is',
#   '...',
#   'virtue',
#   '...'],
#  ['got',
#   'ta',
#   'drop',
#   'off',
#   'some',
#   'car',
#   'parts',
#   'for',
#   'a',
#   'buddy',
#   'to',
#   'press',
#   'out',
#   ',',
#   'then',
#   'to',
#   'the',
#   'dentist',
#   '!'],
#  ['i', 'cant', 'call', 'im', 'at', 'work'],
#  ['going',
#   'to',
#   'the',
#   'courthouse',
#   'to',
#   'pay',
#   'for',
#   'tags',
#   '&',
#   'taxes',
#   'on',
#   'all',
#   'our',
#   'cars',
#   '...',
#   'this',
#   'is',
#   'gon',
#   'na',
#   'be',
#   'expensive',
#   '.'],
#  ['really',
#   'in',
#   'the',
#   'mood',
#   'for',
#   'salt',
#   '&',
#   'pepper',
#   'chicken',
#   'wings',
#   '&',
#   'noodles',
#   'but',
#   'have',
#   'no',
#   'money',
#   'on',
#   'me',
#   'for',
#   'a',
#   'chinese',
#   '!'],
#  ['happy', 'birthday', 'lily', '!'],
#  ['that', 'made', 'my', 'day', 'oh', 'fellow', 'hell', 'ruler'],
#  ['goodnight', 'magic', 'and', 'pretty', 'world'],
#  ['doesnt',
#   'have',
#   'a',
#   'hangover',
#   'and',
#   'is',
#   'getting',
#   'ready',
#   'for',
#   'a',
#   'good',
#   'ol',
#   '`',
#   'english',
#   'fry',
#   'up'],
#  ['boooo'],
#  ['working', 'now'],
#  ['just', 'at', 'starbucks', 'with', 'farrah', '!'],
#  ['ginniejean',
#   'there',
#   '`',
#   's',
#   'a',
#   'lot',
#   'of',
#   'mojo',
#   'all',
#   'over',
#   'the',
#   'place',
#   '...',
#   'yes',
#   '.'],
#  ['!'],
#  ['i', 'miss', 'chomp', 'chomp', 'terribly', '!'],
#  ['is', 'finally', 'starting', 'her', 'assignments'],
#  ['good', 'morning', 'ready', 'to', 'start', 'this', 'week', '.'],
#  ['proly', 'finish', 'it', 'tomorrow', ',', 'after', 'star', 'trek'],
#  ['so', 'glad', 'i', '`', 'm', 'finally', 'done', 'with', 'finals', '!'],
#  ['missing', 'my', 'boo', 'like', 'crrrrrazy', '!'],
#  ['it',
#   'just',
#   'had',
#   'to',
#   'rain',
#   'on',
#   'me',
#   'almost',
#   'a',
#   'perfect',
#   'day',
#   'now',
#   'my',
#   'clothes',
#   'are',
#   'wet'],
#  ['_1',
#   'yeah',
#   'we',
#   'only',
#   'went',
#   'for',
#   '5',
#   'days',
#   'im',
#   'trying',
#   'to',
#   'get',
#   'back',
#   'in',
#   'november',
#   'with',
#   'my',
#   'mom',
#   'for',
#   'super',
#   'soak',
#   'stars',
#   'weekend'],
#  ['but',
#   'if',
#   'i',
#   'come',
#   'bk',
#   'anytime',
#   'b4',
#   'then',
#   'ill',
#   '4',
#   'sure',
#   'let',
#   'u',
#   'kno',
#   '!'],
#  ['let',
#   'him',
#   'know',
#   'he',
#   '`',
#   's',
#   'a',
#   'got',
#   'friend',
#   'in',
#   'us',
#   'aha..'],
#  ['no', 'big', 'deal'],
#  ['trying', 'to', 'figure', 'it', 'out'],
#  ['i',
#   'had',
#   'to',
#   'leave',
#   'him',
#   'at',
#   'the',
#   'vet',
#   'for',
#   'tests',
#   'and',
#   'xrays',
#   '.'],
#  ['went',
#   'to',
#   'see',
#   'hannah',
#   'montana',
#   'movie',
#   'on',
#   'saturday',
#   'loved',
#   'it',
#   '...',
#   '.',
#   'still',
#   'cant',
#   'work',
#   'twitter',
#   'out',
#   'though'],
#  ['lol'],
#  ['fml', '.'],
#  ['just',
#   'got',
#   'confirmed',
#   'that',
#   'itï¿½s',
#   'pizza-time',
#   'with',
#   'some',
#   'ex',
#   'co-workers',
#   'on',
#   'friday',
#   '...',
#   'looking',
#   'forward',
#   'to',
#   'it'],
#  ['well',
#   'paisley',
#   'has',
#   'one',
#   'of',
#   'those',
#   'cone',
#   'things',
#   'around',
#   'her',
#   'head',
#   '...',
#   'so',
#   'funny',
#   'but',
#   'i',
#   'feel',
#   'bad',
#   'for',
#   'her'],
#  ['ugggh',
#   'idk',
#   'how',
#   'to',
#   'do',
#   'that',
#   'but',
#   'i',
#   'only',
#   'wan',
#   'na',
#   'stop',
#   'getting',
#   'texts',
#   'from',
#   'twitterr',
#   '-ilse*'],
#  ['in', 'examination'],
#  ['it',
#   'always',
#   'ended',
#   'up',
#   'with',
#   'me',
#   'selling',
#   'the',
#   'machine',
#   'and',
#   'going',
#   'back',
#   'to',
#   'my',
#   'mac'],
#  ['it',
#   '`',
#   's',
#   'so-so',
#   'only',
#   ',',
#   'not',
#   'so',
#   'much',
#   'action',
#   'but',
#   'i',
#   'feel',
#   'sorry',
#   'for',
#   'marcus',
#   'though',
#   '.'],
#  ['is',
#   'sitting',
#   'thru',
#   'the',
#   'boring',
#   'bits',
#   'in',
#   'titanic',
#   'waiting',
#   'for',
#   'the',
#   'good',
#   'bit',
#   'to',
#   'start',
#   'in',
#   'couple',
#   'of',
#   'hours'],
#  ['-', 'fire', 'and', 'urban', 'at', 'rock', 'challenge'],
#  ['his', 'flight', 'is', 'during', 'my', 'shift', '!'],
#  ['maybe', 'next', 'year'],
#  ['well', 'now', 'i', 'do'],
#  [':', 's'],
#  ['i',
#   'jus',
#   'love',
#   'doin',
#   'night',
#   'shifts',
#   '...',
#   'will',
#   'be',
#   'done',
#   'in',
#   'an',
#   'hour'],
#  ['morning', 'tweeple', ',', 'way', 'to', 'early', 'again'],
#  ['i', 'have', 'to', 'reupload', 'the', '****', 'thing', 'again'],
#  ['how',
#   'was',
#   'the',
#   'prop',
#   'auction',
#   '?',
#   'how',
#   'much',
#   'did',
#   'that',
#   'baseship',
#   'bed',
#   'go',
#   'for',
#   '?'],
#  ['loves',
#   'the',
#   'fact',
#   'that',
#   'there',
#   '`',
#   's',
#   'only',
#   '5',
#   'days',
#   'of',
#   'school',
#   'left'],
#  ['i', 'hope', 'it', '`', 's', 'not', 'bad'],
#  ['hehe'],
#  ['caloric', 'intake', 'off', 'the', 'charts'],
#  [';', ')', 'send', 'me', 'piccies', 'in', 'the', 'email', '!'],
#  ['yay', '!'],
#  ['i', 'can', '`', 't', '.'],
#  ['no', 'kids', 'for', 'this', 'mouse', '.'],
#  ['you', 'okay', 'bby', '?'],
#  [':', ':waves', 'to', 'followers', ':', ':'],
#  ['omg',
#   ',',
#   'my',
#   'mom',
#   'just',
#   'called',
#   '...',
#   'im',
#   'too',
#   'late',
#   '...',
#   'hes',
#   'gone'],
#  ['just',
#   'lost',
#   'my',
#   'internet',
#   'signal',
#   'how',
#   'will',
#   'life',
#   'go',
#   'on'],
#  ['caught',
#   'glimpse',
#   'of',
#   'you',
#   'across',
#   'room',
#   'but',
#   'was',
#   'dragged',
#   'home',
#   'prematurely'],
#  ['__buckley',
#   'good',
#   'for',
#   'you',
#   'mate',
#   ',',
#   'sadly',
#   'i',
#   'couldnt',
#   'get',
#   'pissed',
#   'tonight',
#   '****',
#   'driving',
#   'bad',
#   'times'],
#  ['!'],
#  ['lol'],
#  ['it',
#   '`',
#   's',
#   'mothers',
#   'day',
#   'so',
#   'guess',
#   'who',
#   'im',
#   'eating',
#   'with'],
#  ['very', 'very', 'cute', 'and', 'fun', 'to', 'watch', '.'],
#  ['morning', '!'],
#  ['keeping', 'the', 'faith', 'and', 'looking', 'to', 'the', 'future'],
#  ['guess',
#   'you',
#   'have',
#   'to',
#   'booze',
#   'me..',
#   'or',
#   'just',
#   'ask',
#   'or',
#   'if',
#   'you',
#   'don',
#   '`',
#   't',
#   'believe',
#   'me',
#   '!'],
#  ['not',
#   'going',
#   'to',
#   'the',
#   'dance',
#   'recital',
#   'and',
#   'now',
#   'i',
#   'feel',
#   'like',
#   'a',
#   'piece',
#   'of',
#   '****',
#   'cuz',
#   'it',
#   'cost',
#   'so',
#   'much',
#   'money'],
#  ['goodnight'],
#  ['i', 'can', 'behave', '!'],
#  ['i',
#   'hope',
#   'that',
#   'once',
#   'my',
#   'braces',
#   'go',
#   'on',
#   ',',
#   'i',
#   'can',
#   'eat',
#   'normally',
#   'again'],
#  ['!'],
#  ['and',
#   'dont',
#   'tell',
#   'burnsy',
#   '-',
#   'but',
#   'no',
#   'comparison',
#   'between',
#   'the',
#   'rocky',
#   'mountains',
#   'and',
#   'mountains',
#   'in',
#   'enlgland'],
#  ['i'],
#  ['start', 'runnin'],
#  ['i', '`', 'll', 'go', 'buy', 'it', 'tomorrow'],
#  ['i', 'only', 'ever', 'remember', '222.222'],
#  ['_craig_g',
#   'hope',
#   'your',
#   'enjoying',
#   'the',
#   'money..it',
#   '`',
#   's',
#   'looking',
#   'real',
#   'good',
#   'to',
#   'me',
#   'right',
#   'now'],
#  ['a',
#   ')',
#   'cute',
#   'b',
#   ')',
#   'huggable',
#   'c',
#   ')',
#   'life',
#   'of',
#   'the',
#   'party',
#   '(',
#   'd',
#   ')',
#   '...'],
#  ['have',
#   'been',
#   'sitting',
#   'in',
#   'car',
#   'charging',
#   'phone',
#   'as',
#   'charger',
#   'was',
#   'left',
#   'home',
#   'as',
#   'well'],
#  ['yr', 'congratulatory', 'gweetin', '`'],
#  ['sadly', ',', 'that', '`', 's', 'not', 'too', 'often'],
#  ['star', 'trek', 'was', 'good', 'times', '.'],
#  ['the', 'sun', 'is', 'not', 'cool'],
#  ['lol'],
#  ['honest'],
#  ['it', 'when', 'my', 'ipod', 'randoms', 'bsb', 'songs'],
#  ['totally',
#   'posting',
#   'an',
#   'update',
#   'at',
#   '2am.its',
#   'lightning',
#   'outside',
#   ',',
#   'pretty',
#   '.'],
#  ['a', 'lot', 'of', 'fans', 'here', 'would', 'really', 'love', 'that', '!'],
#  ['has',
#   'broken',
#   'off',
#   'the',
#   'fb',
#   'wedding',
#   'so',
#   'sadly',
#   'no',
#   'longer',
#   'has',
#   'an',
#   'excuse',
#   'to',
#   'get',
#   'hauntingxealot',
#   'to',
#   'goulburn'],
#  ['...', 'you', 'are', 'kickable', '.'],
#  ['_richie',
#   'i',
#   'also',
#   'saw',
#   'u',
#   'on',
#   'american',
#   'idol',
#   'great',
#   'performance',
#   ',',
#   'i',
#   'see',
#   'u',
#   'will',
#   'be',
#   'at',
#   'windsor',
#   'in',
#   'june',
#   '20',
#   'commodores',
#   'won',
#   '`',
#   't',
#   'be',
#   'there'],
#  ['nice', 'clutch'],
#  ['happy', 'mother', '`', 's', 'day', 'to', 'all', 'the', 'mommies'],
#  ['just', 'finished', 'watching', 'marley', 'and', 'me'],
#  ['enjoying', 'mother', '`', 's', 'day'],
#  ['i', 'was', 'really', 'disappointed', '.'],
#  ['roll', 'on', 'thursday'],
#  ['still', 'no', 'freight', 'for', 'carriers', 'out', 'there', '.'],
#  ['cavs',
#   'got',
#   'lucky',
#   '2night',
#   'lol',
#   'but',
#   'lebron',
#   'took',
#   'over',
#   'and',
#   'killed',
#   'em',
#   'another',
#   'triple',
#   'double'],
#  ['!'],
#  ['they',
#   'lose',
#   'it',
#   ',',
#   'i',
#   'refund',
#   ':',
#   'compo',
#   '`',
#   's',
#   'nowhere',
#   'near',
#   '-',
#   'my',
#   'bad'],
#  ['i', 'forgot', 'about', 'that'],
#  ['as',
#   'long',
#   'as',
#   'you',
#   'have',
#   'someone',
#   'to',
#   'make',
#   'out',
#   'with',
#   'lol'],
#  ['ahaha', 'its', 'stuck', 'in', 'my', 'head', ';', 'thanxx'],
#  ['you',
#   'arent',
#   'following',
#   'me',
#   ',',
#   'so',
#   'i',
#   'cant',
#   'send',
#   'you',
#   'a',
#   'dm..'],
#  ['i', '`', 'm', 'poorly', 'and', 'can', '`', 't', 'sleep'],
#  ['happy',
#   'star',
#   'wars',
#   'day',
#   '...',
#   'may',
#   'the',
#   '4th',
#   'be',
#   'with',
#   'you',
#   '...',
#   '.',
#   'read',
#   'for',
#   'more',
#   ';',
#   ')'],
#  ['i',
#   'picked',
#   'up',
#   'a',
#   'taco',
#   'over',
#   'lunch',
#   '...',
#   'you',
#   'got',
#   'a',
#   'guitar',
#   '.'],
#  ['too', 'much', 'to', 'do', '.'],
#  ['!'],
#  ['i',
#   'will',
#   'be',
#   'here',
#   'on',
#   'and',
#   'off',
#   'today',
#   'as',
#   'i',
#   'have',
#   '2',
#   'important',
#   'meetings',
#   'today'],
#  ['_gd',
#   'whoaa',
#   'kinda',
#   'hard',
#   ':',
#   'o',
#   'that',
#   'one',
#   'that',
#   'you',
#   'think',
#   'will',
#   'be',
#   'interesting',
#   'enough',
#   'to',
#   'tell'],
#  ['-', 'i', 'love', 'you', 'guys', 'you', '`', 're', 'the', 'best'],
#  ['!'],
#  ['pedro', 'is', 'supposed', 'to', 'be', 'the', 'mean', 'one'],
#  ['i',
#   'put',
#   'my',
#   '2',
#   'week',
#   '`',
#   's',
#   'notice',
#   'in',
#   'a',
#   'little',
#   'over',
#   'a',
#   'week',
#   'ago',
#   ',',
#   'my',
#   'last',
#   'day',
#   'is',
#   'this',
#   'friday',
#   '!'],
#  ['oh',
#   'yea',
#   'mspacers',
#   'my',
#   'boy',
#   'just',
#   'hooked',
#   'up',
#   'my',
#   'page',
#   'it',
#   'looks',
#   'kewl',
#   'at',
#   'least',
#   'i',
#   'think',
#   'so',
#   'and',
#   'it',
#   'only',
#   'took',
#   'him',
#   '5',
#   'minutes'],
#  ['im', 'getting', 'mine', 'on', 'monday', ',', 'cant', 'wait', 'x'],
#  ['awww',
#   'she',
#   '`',
#   's',
#   'laavly',
#   ';',
#   ')',
#   'i',
#   'had',
#   'to',
#   'come',
#   'in',
#   'but',
#   'i',
#   '`',
#   've',
#   'got',
#   'a',
#   'stunning',
#   'wee',
#   'tan',
#   '(',
#   'l',
#   ')',
#   ';',
#   ')',
#   'yourself',
#   '?'],
#  ['yes',
#   'please',
#   'and',
#   'if',
#   'you',
#   '`',
#   're',
#   'gone',
#   'i',
#   'might',
#   'actually',
#   'get',
#   'some',
#   'work',
#   'done',
#   'lol'],
#  ['sara', '&', 'sami', 'left'],
#  ['so', 'we', 'had', 'to', 'go', '.'],
#  ['?'],
#  ['calling', 'mum', 'too', 'ask', 'if', 'she', 'can', 'by', 'ice-cream'],
#  ['_',
#   'having',
#   'a',
#   'very',
#   'lazy',
#   'day',
#   ',',
#   'playing',
#   'xbox',
#   'and',
#   'drinking',
#   'tea'],
#  ['well', 'thatï¿½s', 'disappointing', 'to', 'hear', '.'],
#  ['and',
#   'by',
#   'the',
#   'time',
#   'im',
#   'back',
#   'it',
#   'will',
#   'be',
#   'over',
#   'hopefully'],
#  ['awwwww', 'i', '`', 'm', 'miss', 'him'],
#  ['happy',
#   'mother',
#   '`',
#   's',
#   'day',
#   'to',
#   'all',
#   'the',
#   'mothers',
#   'out',
#   'there',
#   '!'],
#  ['(',
#   'blinks',
#   'fast',
#   ')',
#   'its',
#   'better',
#   'now',
#   '...',
#   'lol',
#   'thanks',
#   ':',
#   '-*'],
#  ['but',
#   'i',
#   'know',
#   'it',
#   '`',
#   's',
#   'a',
#   'good',
#   'pain',
#   'all',
#   'in',
#   'all',
#   '.'],
#  ['it', '`', 's', 'fun', ',', 'believe', 'me', '!'],
#  ['alas',
#   ',',
#   'i',
#   'am',
#   'moving',
#   '(',
#   'like',
#   'where',
#   'i',
#   '`',
#   'm',
#   'moving',
#   'too',
#   ',',
#   'but',
#   'the',
#   'actual',
#   'moving',
#   ',',
#   'ugh',
#   ')',
#   'wish',
#   'i',
#   'could',
#   'go',
#   'too',
#   '!'],
#  ['ready', 'to', 'go', 'home'],
#  ['better', 'than', 'a', 'gain'],
#  ['ia',
#   'm',
#   'excited',
#   'itï¿½s',
#   'gon',
#   'na',
#   'be',
#   'funny..',
#   'but',
#   'before',
#   'i',
#   'have',
#   'to',
#   'carry',
#   'all',
#   'the',
#   'equipment',
#   'and',
#   'do',
#   'the',
#   'backline'],
#  ['it',
#   'won',
#   '`',
#   't',
#   'keep',
#   'me',
#   'from',
#   'dropping',
#   'it',
#   'low',
#   '...',
#   'hope',
#   'i',
#   'got',
#   'someone',
#   'to',
#   'pick',
#   'it',
#   'back',
#   'up',
#   'tho',
#   '...',
#   'lol'],
#  ['facebook', 'is', 'being', 'a', '****'],
#  ['mad',
#   'the',
#   'rain',
#   'got',
#   'me',
#   '...',
#   'now',
#   'i',
#   'cant',
#   'go',
#   'see',
#   'jaiden',
#   '*|',
#   ')',
#   '|/-\\|\\|/-\\*'],
#  ['i', 'am', 'at', 'my', 'grandparents', 'place'],
#  ['it',
#   '`',
#   's',
#   '9',
#   'deg',
#   'c',
#   'winter',
#   '`',
#   's',
#   'coming',
#   '...',
#   '.cant',
#   'wait',
#   'for',
#   'cali',
#   'sun',
#   '.'],
#  ['i', 'dont', 'feel', 'very', 'good'],
#  ['i', 'was', 'born', 'there'],
#  ['congradts',
#   'on',
#   'ur',
#   'show',
#   'even',
#   'tho',
#   'i',
#   'wasnt',
#   'there',
#   'lol'],
#  ['damjust',
#   'finished',
#   'watching',
#   'prison',
#   'break',
#   ':',
#   'the',
#   'final',
#   'break',
#   '...',
#   'omg',
#   'i',
#   'dont',
#   'think',
#   'i',
#   '`',
#   've',
#   'cried',
#   'so',
#   'hard',
#   'for',
#   'a',
#   'show..finally',
#   'understand',
#   'the',
#   'finale'],
#  ['i',
#   'wish',
#   'i',
#   'had',
#   'an',
#   'excuse',
#   'to',
#   'be',
#   'so',
#   'tired',
#   'today..'],
#  ['too', 'bad', 'it', 'isnt', 'nice', 'and', 'warm', 'out', 'today'],
#  ['finally',
#   'your',
#   'long',
#   'time',
#   'will',
#   'of',
#   'panvel',
#   'tweetup',
#   'finally',
#   'coming',
#   'true..'],
#  ['!'],
#  ['this',
#   'weekend',
#   'is',
#   'going',
#   'to',
#   'be',
#   'packed',
#   'full',
#   'of',
#   'work',
#   'for',
#   'school',
#   'no',
#   'life',
#   'this',
#   'summer',
#   'i',
#   '`',
#   'm',
#   'afraid',
#   '.'],
#  ['please',
#   'read',
#   'my',
#   'blog',
#   'i',
#   '`',
#   'm',
#   'not',
#   'having',
#   'the',
#   'best',
#   'day'],
#  ['_aid16', 'goodnight', '!'],
#  ['welcome'],
#  ['actually',
#   ',',
#   'steve',
#   'only',
#   'has',
#   '6',
#   'staffers',
#   'in',
#   '3',
#   'offices',
#   '.'],
#  ['thanks', ',', 'none', 'close', 'to', 'me', '.'],
#  ['off', 'out', 'with', 'freddie', 'for', 'a', 'fun-packed', 'day'],
#  ['haha', 'i', 'will', 'remember', 'that', '****'],
#  ['haha', 'hopeless', 'me'],
#  ['i', 'sorry'],
#  ['awww',
#   ',',
#   'it',
#   'does',
#   'remind',
#   'me',
#   'of',
#   'getting',
#   'ready',
#   'for',
#   'the',
#   'ball',
#   '.'],
#  ['!'],
#  ['_bishop',
#   'sez',
#   'need',
#   'to',
#   'get',
#   'u',
#   'to',
#   'look',
#   'at',
#   'my',
#   'flights',
#   'again',
#   'will',
#   'email',
#   'ur',
#   'work',
#   'tonite'],
#  ['i',
#   'wish',
#   'i',
#   'had',
#   'the',
#   'battery',
#   'life',
#   'of',
#   'an',
#   'iphone',
#   '!'],
#  ['nite',
#   'nite',
#   'twitts',
#   'i',
#   'wish',
#   'u',
#   'all',
#   'a',
#   'happy',
#   'sunday',
#   'i',
#   'already',
#   'have',
#   'my',
#   'major',
#   'gift',
#   'my',
#   'my',
#   '2kids-my',
#   'bro-n',
#   'n',
#   '1',
#   'other',
#   'gift',
#   'on',
#   'd',
#   'way',
#   'tyg'],
#  ['i', 'am', 'glued', 'to', 'the', 'screen'],
#  ['at',
#   'first',
#   'i',
#   'thought',
#   'bar',
#   'life',
#   'meant',
#   'you',
#   'were',
#   'partying',
#   'nonstop',
#   'to',
#   'catch',
#   'up',
#   'for',
#   'the',
#   'last',
#   '2',
#   'years',
#   '...',
#   'lol',
#   'shoulda',
#   'known',
#   'better'],
#  ['work', 'in', 'that', 'heat', 'is', 'horrible', '!'],
#  ['someone',
#   'came',
#   'in',
#   'when',
#   'i',
#   'was',
#   'sleeping',
#   'off',
#   'my',
#   'national',
#   'passtime',
#   'and',
#   'turned',
#   'me',
#   'human'],
#  ['your', 'hair', '`', 's', 'too', 'pretty', '!'],
#  ['_starr',
#   'yep',
#   ',',
#   'the',
#   'hawkesbury',
#   'classic',
#   'starts',
#   'at',
#   'windsor',
#   ',',
#   'home',
#   'of',
#   'said',
#   'dj'],
#  ['thanks', 'savvv'],
#  ['my',
#   'sleep',
#   'pattern',
#   'is',
#   'screwed',
#   'i',
#   'need',
#   'to',
#   'try',
#   'and',
#   'stay',
#   'up',
#   '2',
#   'midnight',
#   'so',
#   'i',
#   'can',
#   'get',
#   'some',
#   'decent',
#   'sleep',
#   'coz',
#   'i',
#   'havent',
#   'slept'],
#  ['since',
#   'the',
#   'demise',
#   'of',
#   'woolworths',
#   'it',
#   'isn',
#   '`',
#   't',
#   'easy',
#   'to',
#   'find',
#   'reasonably',
#   'priced',
#   'pick',
#   'n',
#   'mix',
#   'anywhere'],
#  ['happy', 'star', 'wars', 'day'],
#  ['gottta',
#   'make',
#   'my',
#   'own',
#   'luck',
#   'and',
#   'that',
#   'involves',
#   '$',
#   '$',
#   '$',
#   '$',
#   '$'],
#  ['taking', 'care', 'of', 'yucky', 'stuff', '.'],
#  ...]

# %%
model_cbow = gensim.models.Word2Vec(
    data,
    min_count = 1,
    size = 100,
    window = 5
)

# %%
print("Cosine similarity between 'funny' " + 
               "and 'awesome' - CBOW : ",
    model_cbow.similarity('funny', 'wonderland'))
      
print("Cosine similarity between 'sad' " +
                 "and 'bad' - CBOW : ",
      model_cbow.similarity('sad', 'bad'))
# Out:
# Cosine similarity between 'funny' and 'awesome' - CBOW :  0.5749547
# Cosine similarity between 'sad' and 'bad' - CBOW :  0.9739759
# /Users/cosmin/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/cosmin/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   import sys

# %%
model_sg = gensim.models.Word2Vec(
    data,
    min_count = 1,
    size = 100,
    window = 5,
    sg = 1
)

# %%
print("Cosine similarity between 'funny' " + 
               "and 'awesome' - Skip gram : ",
    model_sg.similarity('funny', 'wonderland'))
      
print("Cosine similarity between 'sad' " +
                 "and 'bad' - Skip gram : ",
      model_sg.similarity('sad', 'bad'))
# Out:
# Cosine similarity between 'funny' and 'awesome' - Skip gram :  0.75168175
# Cosine similarity between 'sad' and 'bad' - Skip gram :  0.89356714
# /Users/cosmin/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/cosmin/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   import sys

# %%
model_sg.wv.vectors
# Out:
# array([[-0.09886577,  0.40992126, -0.2907177 , ...,  0.20723571,
#         -0.6223622 ,  0.14726076],
#        [-0.37167954,  0.6341782 , -0.14609143, ...,  0.06368072,
#         -0.47070983,  0.33830035],
#        [-0.3543362 ,  0.298599  , -0.09627043, ...,  0.0652901 ,
#         -0.5178383 ,  0.20937568],
#        ...,
#        [-0.02685356,  0.05414843,  0.04435802, ..., -0.00264727,
#         -0.05130376,  0.02970337],
#        [-0.02750463,  0.05693062,  0.0659005 , ..., -0.02529236,
#         -0.02657408,  0.02523087],
#        [-0.01193203,  0.03166804,  0.0427084 , ..., -0.01946358,
#         -0.01451666,  0.0212598 ]], dtype=float32)

# %%
model_sg.wv.vector_size
# Out:
# 100

# %%
max_words = 5000
model = Sequential()
model.add(layers.Embedding(
    len(model_sg.wv.vocab),
    model_sg.wv.vector_size,
    weights=[model_sg.wv.vectors],
    trainable=False
))
model.add(layers.Bidirectional(layers.LSTM(50,return_sequences=True)))
model.add(layers.Bidirectional(layers.LSTM(50)))
model.add(layers.Dense(3,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 100)         2117500
# _________________________________________________________________
# bidirectional (Bidirectional (None, None, 100)         60400
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 100)               60400
# _________________________________________________________________
# dense (Dense)                (None, 3)                 303
# =================================================================
# Total params: 2,238,603
# Trainable params: 121,103
# Non-trainable params: 2,117,500
# _________________________________________________________________

# %% [markdown]
# # Utilizare embedding-uri GloVe
#
# https://nlp.stanford.edu/projects/glove/
# https://blog.keras.io/using-pre-trained-word-embeddings-in-a-keras-model.html
